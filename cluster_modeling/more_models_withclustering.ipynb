# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style('whitegrid')

from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error

# %% [markdown]
# In this notebook, we explore possible improvements upon the models introduced earlier, as well as assess the effectiveness of new models. In both cases, much anticipation is built upon the inclusion of the 2021 census data.

# %%
#load the restaurant dataset with census features
rd_train = pd.read_csv("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/final_level1_train_data.csv")

#load the list of features deemed most impactful
with open("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/final_features.csv", "r") as file:
    next(file)
    features = [line.strip() for line in file]
    
features
# Out:
# ['latitude',
#  'longitude',
#  'photos_count',
#  'reviews',
#  'Median Household Income',
#  'Education Level %',
#  '% Black',
#  '% Hispanic/Latino',
#  'Foreign Born Immigrant %',
#  'Median Age']

# %% [markdown]
# We remind the reader that this dataset only presents for the restaurants of price level 1.

# %%
#check for NA values (in order to run the regressions)
rd_train.isna().sum(axis = 0)
# Out:
# name                          0
# site                          0
# subtypes                      0
# category                      0
# type                          0
# phone                         0
# full_address                  0
# borough                       0
# street                        1
# postal_code                   0
# latitude                      0
# longitude                     0
# h3                            0
# rating                        0
# reviews                       0
# reviews_link                  0
# reviews_per_score_1           0
# reviews_per_score_2           0
# reviews_per_score_3           0
# reviews_per_score_4           0
# reviews_per_score_5           0
# photos_count                  0
# photo                         0
# working_hours_old_format     26
# other_hours                 703
# business_status               0
# about                         0
# range                         0
# description                 450
# booking_appointment_link      0
# location_link                 0
# location_reviews_link         0
# place_id                      0
# google_id                     0
# cid                           0
# kgmid                         0
# reviews_id                    0
# census_tract                  0
# Median Household Income      12
# Poverty Rate %                3
# Education Level %             0
# Total Population              0
# % White                       0
# % Black                       0
# % Asian                       0
# % Hispanic/Latino             0
# Foreign Born Immigrant %      0
# Median Age                    0
# Neighborhood Turnover %       0
# state                         0
# county                        0
# tract                         0
# dtype: int64

# %%
#drop rows with missing "Median Household Income" values
rd_train.dropna(axis = 0, subset = 'Median Household Income', inplace = True, ignore_index= True)

# %% [markdown]
# In this notebook, we shall explore three new models:
# 1) 'K Neighbors Regression' with all of the features listed in "features_importances.csv" that have importance higher than 0.05;
#
# 2) 'Random Forest Regression' with those same features;
#
# 3) 'Random Forest Regression with K Neighbors Boost'
#
#
# and we shall also develop a new form of clustering aimed at improved estimates in subsets of the data misfitted by all models including the above. This clustering will occur manually, by way of decision tree classification.

# %% [markdown]
# ## Model 1 (K Neighbors Regression)

# %%
#make stratified k-fold object
n_splits = 5
kfold = StratifiedKFold(n_splits, shuffle = True, random_state= 5501)

# %%
#prepare the index set for 'rmse' dataframe tracking value of k and borough of each restaurant
boroughs = np.sort(rd_train.borough.unique())
num_k = 20

many_boroughs = np.array([])
many_ks = []
for i in range(num_k): 
    many_boroughs = np.concatenate((boroughs, many_boroughs))
    many_ks = many_ks + len(boroughs)*[i]

# %%
features1 = features[:7]

# %%
features1
# Out:
# ['latitude',
#  'longitude',
#  'photos_count',
#  'reviews',
#  'Median Household Income',
#  'Education Level %',
#  '% Black']

# %%
rmse = np.zeros((num_k, n_splits))

rmse_df = pd.DataFrame({"borough": many_boroughs, "k": many_ks})
for k in range(num_k):
    knn_pipe = Pipeline([('scale', StandardScaler()), ('knn', KNeighborsRegressor(k+1))])
    i = 0
    for train_index, test_index in kfold.split(rd_train, rd_train.borough):
         rd_t_train= rd_train.iloc[train_index]
         rd_t_test = rd_train.iloc[test_index]

         knn_pipe.fit(rd_t_train[features1], rd_t_train.rating)
         preds = knn_pipe.predict(rd_t_test[features1])
         rmse[k, i] = root_mean_squared_error(rd_t_test.rating, preds)
         
         for bor in rd_t_test.borough.unique():
              rd_t_bor = rd_t_test[rd_t_test.borough == bor]
              bor_preds = knn_pipe.predict(rd_t_bor[features1])
              rmse_df.loc[(rmse_df.borough == bor) &(rmse_df.k == k), i] = root_mean_squared_error(rd_t_test[rd_t_test.borough == bor].rating,
                                                                               bor_preds)
         
         i += 1
# Out:
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
#add column with average of the available rmse's
rmse_df['Avg. RMSE'] = rmse_df.iloc[:, -5:].sum(axis = 1)/(n_splits - rmse_df.isna().sum(axis = 1))

#find the best k for each borough
def find_k(data, borough):
    df = data[data.borough == borough]
    return np.argmin(df['Avg. RMSE']) + 1

best_ks = [find_k(rmse_df, bor) for bor in boroughs]

min_rmses = [rmse_df.loc[(rmse_df.k == best_ks[i] -1) & 
                         (rmse_df.borough == boroughs[i]), 'Avg. RMSE'].reset_index(drop=True)[0] for i in range(len(boroughs))]


#give the desired dataframe of rmse with best k-neighbors model for each borough
rmse = np.mean(rmse, axis = 1)
min_k = np.argmin(rmse)
gen_k_neigh = pd.DataFrame({'Borough': boroughs, "Best k": best_ks, "CV Avg. RMSE": min_rmses})
print(f"The overall CV avg. RMSE is {rmse[min_k]: .3f} with k = {min_k + 1}. The dataframe below presents the best k-neighbors results individualized to each borough.")
gen_k_neigh['Number of Restaurants'] = [len(rd_train[rd_train.borough == bor]) for bor in boroughs]
gen_k_neigh
# Out:
# The overall CV avg. RMSE is  0.440 with k = 18. The dataframe below presents the best k-neighbors results individualized to each borough.
#                     Borough  Best k  CV Avg. RMSE  Number of Restaurants
# 0            Allegheny West      16      0.350360                      9
# 1               Bella Vista      14      0.286226                      9
# 2                  Bensalem      19      0.538596                      3
# 3               Center City      12      0.430627                     25
# 4          Center City East      20      0.442763                     49
# 5             Chestnut Hill      10      0.304538                      8
# 6           East Germantown       4      0.382769                     13
# 7           East Kensington      16      0.085417                      3
# 8    East Passyunk Crossing       5      0.282390                      6
# 9              Elmwood Park      19      0.324644                     18
# 10                Essington      10      0.237500                      4
# 11                 Fairhill      16      0.349226                     13
# 12                Fairmount       5      0.253036                     12
# 13              Feltonville       9      0.247131                     12
# 14                 Fishtown       7      0.249687                      8
# 15                Fox Chase      20      0.399579                     11
# 16                Frankford      17      0.261632                     16
# 17               Germantown      10      0.287114                      8
# 18               Harrowgate      20      0.258000                      5
# 19              Kingsessing      15      0.346250                      6
# 20                   Lester       1      0.000000                      2
# 21        Lower Moyamensing      20      0.188000                      5
# 22                 Manayunk       4      0.287500                      2
# 23               Mount Airy      20      0.381802                     12
# 24                  Newbold      17      0.370747                     11
# 25           Nicetown–Tioga       2      0.275000                      4
# 26       North Philadelphia      20      0.443708                     52
# 27  North Philadelphia East       7      0.481564                     39
# 28   Northeast Philadelphia      16      0.448444                    178
# 29       Northern Liberties       5      0.251662                      6
# 30   Northwest Philadelphia       1      0.000000                      1
# 31                   Ogontz      20      0.367423                      8
# 32          Olde Kensington       2      0.100000                      2
# 33            Olde Richmond       7      0.462857                      5
# 34           Olney-Oak Lane      16      0.331132                     38
# 35                Pennsport      12      0.191667                      2
# 36            Port Richmond       4      0.340023                     21
# 37       Rittenhouse Square       8      0.135234                     10
# 38      Roxborough-Manayunk       4      0.420059                     46
# 39       South Philadelphia       7      0.405132                     57
# 40  South Philadelphia East       8      0.363845                     11
# 41                Southwark       5      0.210319                      8
# 42    Southwest Center City       1      0.411447                      8
# 43   Southwest Philadelphia      20      0.269741                     10
# 44                  Stanton      20      0.251667                      3
# 45                  Stenton      18      0.455942                     18
# 46       Strawberry Mansion       7      0.313005                     11
# 47                   Tacony       1      0.288222                     11
# 48                Unlabeled      11      0.342930                     11
# 49        West Philadelphia      13      0.498619                    113
# 50                  Whitman       2      0.150000                      4

# %% [markdown]
# ## Model 2 (Random Forest Regression)

# %%
#run random forest model on the dataset with same features                                  

random_for = RandomForestRegressor(n_estimators=100, max_depth = 4, random_state=59038, max_features = len(features))
rmse_bor = pd.DataFrame(index = boroughs)
rmse = np.zeros(n_splits)
i = 0
for train_index, test_index in kfold.split(rd_train, rd_train.borough):
    rd_t_train= rd_train.iloc[train_index]
    rd_t_test = rd_train.iloc[test_index]

    random_for.fit(rd_t_train[features1], rd_t_train.rating)
    preds = random_for.predict(rd_t_test[features1])
    rmse[i] = root_mean_squared_error(rd_t_test.rating, preds)
         
    for bor in rd_t_test.borough.unique():
        rd_t_bor = rd_t_test[rd_t_test.borough == bor]
        bor_preds = random_for.predict(rd_t_bor[features1])
        rmse_bor.loc[bor, i] = root_mean_squared_error(rd_t_test[rd_t_test.borough == bor].rating,
                                                                               bor_preds)
         
    i += 1



print(f"The overall CV avg. RMSE is {np.mean(rmse): .3f}.")
rmse_bor.mean(axis = 1)
# Out:
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# The overall CV avg. RMSE is  0.436.
# Allegheny West             0.372813
# Bella Vista                0.290395
# Bensalem                   0.627050
# Center City                0.453729
# Center City East           0.439015
# Chestnut Hill              0.347609
# East Germantown            0.418608
# East Kensington            0.130975
# East Passyunk Crossing     0.381582
# Elmwood Park               0.303195
# Essington                  0.540986
# Fairhill                   0.392209
# Fairmount                  0.310260
# Feltonville                0.303520
# Fishtown                   0.309104
# Fox Chase                  0.411625
# Frankford                  0.280205
# Germantown                 0.308672
# Harrowgate                 0.222498
# Kingsessing                0.292379
# Lester                     0.394069
# Lower Moyamensing          0.230159
# Manayunk                   0.348218
# Mount Airy                 0.438567
# Newbold                    0.403814
# Nicetown–Tioga             0.501395
# North Philadelphia         0.444015
# North Philadelphia East    0.500764
# Northeast Philadelphia     0.449855
# Northern Liberties         0.288462
# Northwest Philadelphia     0.119654
# Ogontz                     0.371099
# Olde Kensington            0.250815
# Olde Richmond              0.427116
# Olney-Oak Lane             0.346050
# Pennsport                  0.208383
# Port Richmond              0.362163
# Rittenhouse Square         0.203792
# Roxborough-Manayunk        0.427379
# South Philadelphia         0.416932
# South Philadelphia East    0.422508
# Southwark                  0.270914
# Southwest Center City      0.572951
# Southwest Philadelphia     0.340922
# Stanton                    0.264581
# Stenton                    0.459739
# Strawberry Mansion         0.341078
# Tacony                     0.311374
# Unlabeled                  0.294557
# West Philadelphia          0.494754
# Whitman                    0.287945
# dtype: float64

# %% [markdown]
# ## Model 3 (Random Forest with K Neighbors Boost)

# %%
features2 = features1.copy()
features2.remove('% Black')

num_k = 30
rmse = np.zeros((num_k, n_splits))

rmse_df = pd.DataFrame({"borough": many_boroughs, "k": many_ks})
for k in range(num_k):
    knn_pipe = Pipeline([('scale', StandardScaler()), ('knn', KNeighborsRegressor(k+1))])
    i = 0
    for train_index, test_index in kfold.split(rd_train, rd_train.borough):
        rd_t_train= rd_train.iloc[train_index]
        rd_t_test = rd_train.iloc[test_index]
        random_for.fit(rd_t_train[features1], rd_t_train.rating)
        preds_tr = random_for.predict(rd_t_train[features1])
        resids_tr = rd_t_train.rating - preds_tr
        knn_pipe.fit(rd_t_train[features2], resids_tr)

        preds = random_for.predict(rd_t_test[features1])
        new_resids = knn_pipe.predict(rd_t_test[features2])
        rmse[k, i] = root_mean_squared_error(rd_t_test.rating, new_resids + preds)
         
        for bor in rd_t_test.borough.unique():
            rd_t_bor = rd_t_test[rd_t_test.borough == bor]
            bor_preds = random_for.predict(rd_t_bor[features1])
            bor_resids = knn_pipe.predict(rd_t_bor[features2])
            rmse_df.loc[(rmse_df.borough == bor) &(rmse_df.k == k), i] = root_mean_squared_error(rd_t_bor.rating,
                                                                               bor_preds + bor_resids)
         
        i += 1
# Out:
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
#add column with average of the available rmse's
rmse_df['Avg. RMSE'] = rmse_df.iloc[:, -5:].sum(axis = 1)/(n_splits - rmse_df.isna().sum(axis = 1))

#find the best k
best_ks = [find_k(rmse_df, bor) for bor in boroughs]

min_rmses = [rmse_df.loc[(rmse_df.k == best_ks[i] -1) & 
                         (rmse_df.borough == boroughs[i]), 'Avg. RMSE'].reset_index(drop=True)[0] for i in range(len(boroughs))]


#give the desired dataframe
rmse = np.mean(rmse, axis = 1)
min_k = np.argmin(rmse)
gen_k_neigh_boost = pd.DataFrame({'Borough': boroughs, "Best k": best_ks, "CV Avg. RMSE": min_rmses})
print(f"The overall CV avg. RMSE is {rmse[min_k]: .3f} with k = {min_k + 1}.")
gen_k_neigh_boost['Number of Restaurants'] = [len(rd_train[rd_train.borough == bor]) for bor in boroughs]
gen_k_neigh_boost
# Out:
# The overall CV avg. RMSE is  0.440 with k = 29.
#                     Borough  Best k  CV Avg. RMSE  Number of Restaurants
# 0            Allegheny West      20      0.329755                      9
# 1               Bella Vista       2      0.284016                      9
# 2                  Bensalem       8      0.643545                      3
# 3               Center City       1      0.420236                     25
# 4          Center City East      19      0.452137                     49
# 5             Chestnut Hill      10      0.340694                      8
# 6           East Germantown      20      0.432569                     13
# 7           East Kensington       2      0.110087                      3
# 8    East Passyunk Crossing      12      0.337783                      6
# 9              Elmwood Park      19      0.291469                     18
# 10                Essington       2      0.249563                      4
# 11                 Fairhill      19      0.371189                     13
# 12                Fairmount      12      0.282934                     12
# 13              Feltonville      18      0.286943                     12
# 14                 Fishtown       5      0.252436                      8
# 15                Fox Chase       5      0.428208                     11
# 16                Frankford      16      0.285400                     16
# 17               Germantown       9      0.318710                      8
# 18               Harrowgate       6      0.264654                      5
# 19              Kingsessing       6      0.279502                      6
# 20                   Lester       1      0.030180                      2
# 21        Lower Moyamensing       9      0.205331                      5
# 22                 Manayunk       4      0.280621                      2
# 23               Mount Airy      18      0.427311                     12
# 24                  Newbold      18      0.391313                     11
# 25           Nicetown–Tioga       3      0.437630                      4
# 26       North Philadelphia      15      0.456725                     52
# 27  North Philadelphia East       4      0.434876                     39
# 28   Northeast Philadelphia      14      0.452897                    178
# 29       Northern Liberties       3      0.225517                      6
# 30   Northwest Philadelphia       1      0.069510                      1
# 31                   Ogontz      20      0.358869                      8
# 32          Olde Kensington       2      0.175174                      2
# 33            Olde Richmond       9      0.445677                      5
# 34           Olney-Oak Lane      17      0.356424                     38
# 35                Pennsport      14      0.194270                      2
# 36            Port Richmond       4      0.353221                     21
# 37       Rittenhouse Square       8      0.156630                     10
# 38      Roxborough-Manayunk       2      0.424926                     46
# 39       South Philadelphia      10      0.404674                     57
# 40  South Philadelphia East       6      0.342341                     11
# 41                Southwark       2      0.212243                      8
# 42    Southwest Center City       1      0.421500                      8
# 43   Southwest Philadelphia      12      0.317960                     10
# 44                  Stanton      20      0.282783                      3
# 45                  Stenton      15      0.479545                     18
# 46       Strawberry Mansion       6      0.335346                     11
# 47                   Tacony      20      0.336777                     11
# 48                Unlabeled      17      0.289401                     11
# 49        West Philadelphia      20      0.501147                    113
# 50                  Whitman       2      0.193174                      4

# %% [markdown]
# ## Model Comparisons

# %% [markdown]
# Let us compare this with all of our 'k neighbors' models.

# %% [markdown]
# Recall for below that the first 'k neighbors' model applies to all price level 1 restaurants throughout Philly with features of latitude/longitude, reviews, photos count, and cuisine specification. The second model similarly applies to all level 1 restaurants with only features of latitude/longitude taken, while the third relies on the same features yet only picks 'k'-many neighbors within the same borough as the data point tested.

# %%
old_rmse = pd.read_csv("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/level1_modelcomparison.csv")
old_rmse.index = boroughs

old_rmse
# Out:
#                          Best k  CV Avg. RMSE  Best k.1  CV Avg. RMSE.1  \
# Allegheny West               38      0.269954         5        0.317933
# Bella Vista                   1      0.242120         4        0.192432
# Bensalem                      2      0.166667        48        0.519444
# Center City                  12      0.375324        21        0.457391
# Center City East              2      0.414297        50        0.454809
# Chestnut Hill                 1      0.369610        38        0.372912
# East Germantown              15      0.302769        22        0.420062
# East Kensington               2      0.083333        16        0.118750
# East Passyunk Crossing        1      0.284721        13        0.351479
# Elmwood Park                 10      0.344593         4        0.334522
# Essington                    23      0.421739         1        0.325000
# Fairhill                     11      0.267780        23        0.341972
# Fairmount                     7      0.342819         4        0.321080
# Feltonville                  24      0.232794        47        0.365689
# Fishtown                      5      0.531558        13        0.175108
# Fox Chase                     9      0.324839         5        0.412740
# Frankford                    13      0.275483        14        0.338548
# Germantown                    7      0.281291        50        0.434183
# Harrowgate                    3      0.080000        15        0.190667
# Kingsessing                   1      0.178995        12        0.218333
# Lester                        1      0.300000         1        0.000000
# Lower Moyamensing             5      0.112000        45        0.187556
# Manayunk                     27      0.370370        50        0.349000
# Mount Airy                   16      0.372976        21        0.386997
# Newbold                       2      0.248947        42        0.358070
# Nicetown–Tioga                3      0.300000         4        0.285000
# North Philadelphia            3      0.341276        46        0.419899
# North Philadelphia East       8      0.413525         5        0.510337
# Northeast Philadelphia        6      0.411141        49        0.456361
# Northern Liberties            3      0.174115         7        0.206860
# Northwest Philadelphia       24      0.000000         1        0.000000
# Ogontz                        7      0.257596         6        0.289484
# Olde Kensington              10      0.305000        10        0.120000
# Olde Richmond                13      0.184615         3        0.220000
# Olney-Oak Lane                2      0.305507        32        0.334991
# Pennsport                     1      0.463217         7        0.379136
# Port Richmond                 3      0.322582         5        0.295440
# Rittenhouse Square            1      0.292633         2        0.175955
# Roxborough-Manayunk           5      0.427720         3        0.437176
# South Philadelphia            5      0.348565        27        0.423924
# South Philadelphia East       1      0.228353        38        0.367242
# Southwark                     6      0.299661        18        0.303572
# Southwest Center City         4      0.392790         2        0.282219
# Southwest Philadelphia        3      0.454615         2        0.375827
# Stanton                       1      0.133333        31        0.173118
# Stenton                       2      0.243011         6        0.417907
# Strawberry Mansion            7      0.341542        50        0.368267
# Tacony                        9      0.207216        27        0.224761
# Unlabeled                     2      0.277737         4        0.317369
# West Philadelphia             8      0.450909        19        0.476109
# Whitman                       6      0.116667         8        0.275000
#
#                          Best k.2  Min. RMSE  Number of Restaurants
# Allegheny West                  6   0.385603                     10
# Bella Vista                     5   0.230552                      9
# Bensalem                        0   1.000000                      3
# Center City                     5   0.419394                     25
# Center City East               11   0.431824                     49
# Chestnut Hill                   6   0.412998                      8
# East Germantown                10   0.422507                     13
# East Kensington                 0   1.000000                      3
# East Passyunk Crossing          4   0.413310                      6
# Elmwood Park                   11   0.359574                     18
# Essington                       0   1.000000                      4
# Fairhill                        6   0.372925                     13
# Fairmount                       2   0.252941                     12
# Feltonville                    10   0.370638                     14
# Fishtown                        5   0.044778                      8
# Fox Chase                       2   0.353452                     11
# Frankford                      10   0.353712                     17
# Germantown                      6   0.327235                      8
# Harrowgate                      0   1.000000                      5
# Kingsessing                     4   0.290178                      6
# Lester                          0   1.000000                      2
# Lower Moyamensing               0   1.000000                      5
# Manayunk                        0   1.000000                      2
# Mount Airy                      5   0.453279                     12
# Newbold                         5   0.371147                     11
# Nicetown–Tioga                  0   1.000000                      5
# North Philadelphia             39   0.409986                     56
# North Philadelphia East         3   0.511330                     40
# Northeast Philadelphia        134   0.451666                    181
# Northern Liberties              4   0.262195                      6
# Northwest Philadelphia          0   1.000000                      1
# Ogontz                          5   0.417387                      8
# Olde Kensington                 0   1.000000                      2
# Olde Richmond                   0   1.000000                      5
# Olney-Oak Lane                 16   0.329954                     39
# Pennsport                       3   0.409402                      7
# Port Richmond                   5   0.269891                     21
# Rittenhouse Square              3   0.119987                     10
# Roxborough-Manayunk             3   0.408528                     46
# South Philadelphia             33   0.429447                     64
# South Philadelphia East         2   0.368117                     12
# Southwark                       4   0.289090                      8
# Southwest Center City           2   0.482667                      8
# Southwest Philadelphia          4   0.424026                     20
# Stanton                         0   1.000000                      3
# Stenton                        14   0.438309                     18
# Strawberry Mansion              8   0.352460                     11
# Tacony                          6   0.292815                     11
# Unlabeled                       6   0.220758                     11
# West Philadelphia              16   0.496887                    114
# Whitman                         0   1.000000                      4

# %%
#write all results to file for visual analysis
df = pd.concat([old_rmse.iloc[:, :-1], gen_k_neigh.set_index('Borough').iloc[:, :2], 
                rmse_bor.mean(axis = 1).rename('RF CV RMSE'), gen_k_neigh_boost.set_index('Borough').iloc[:, :3]], axis = 1)

df.to_csv("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/allmodels_comparison(level1).csv")

# %% [markdown]
# If we only look at overall CV avg. RMSE, all of these models seem to perform similarly. However, k has to be taken rather large for k neighbors regression, so random forest regression seems most efficient.
#
# But we note that a subset of the models pursued produce better estimates for certain boroughs where other models perform badly.
#
# Thus, it seems further confirmed that we could improve our estimates if we cluster.

# %% [markdown]
# ## Clustering

# %% [markdown]
# First, we present evidence showing the benefit for clustering. Choosing for each borough the model that performs best there, we obtain a significantly lower avg. CV RMSE than attained at any previous point.

# %%
#combine all models for '$' restaurants

rf_rmse = rmse_bor.mean(axis = 1)
sum = 0
for bor in boroughs:
    array1 = old_rmse.loc[bor, ['CV Avg. RMSE', 'CV Avg. RMSE.1', 'Min. RMSE']].values
    array2 = [rf_rmse[bor]]
    tally = old_rmse.loc[bor, 'Number of Restaurants']
    err = np.min(np.concatenate((array1, array2)))
    sum += tally*err**2
total = old_rmse['Number of Restaurants'].sum()
np.sqrt(sum/total)
# Out:
# np.float64(0.35397367569012683)

# %% [markdown]
# For the future, we shall certainly organize our data into clusters by boroughs. However, this is only one tier in our overall clustering strategy. The next tier, introduced in the next section, is a form of clustering that occurs within boroughs- those boroughs whose dining culture is so complex as to encompass widely differing trends.

# %% [markdown]
# ### Clustering for West Philly

# %% [markdown]
# 'West Philadelphia' is one of the boroughs where our analysis has persistently performed the worst. This fact seems to imply that there is greater complexity to West Philly than what one single regression model can grasp. Therefore, we use its corresponding dataset to demonstrate the new clustering scheme.

# %%
features_wp = ['reviews', 'longitude', 'latitude', 'photos_count', '% Black', 'Education Level %', 'Foreign Born Immigrant %']

# %% [markdown]
# The clustering scheme we have in mind is essentially a 'greedy algorithm'. First, we check for the best performing model. And then we assess where the model performs badly, obtaining a feature-based description of this set. Finally, we test various models on this set and select the one that performs best there.

# %%
west_ph = rd_train[(rd_train.borough == 'West Philadelphia')]
west_ph = pd.concat([west_ph, pd.get_dummies(west_ph.type)], axis = 1)
features_wp = features_wp + west_ph.columns[52:].to_list()

# %%
rmse_wp = np.zeros(n_splits)
rf_wp = RandomForestRegressor(max_depth = 4, random_state=59038, max_features = len(features))
kfold1 = KFold(n_splits = 5, random_state= 5501, shuffle=True)
i=0
for train_index, test_index in kfold1.split(west_ph):
    train_set = west_ph.iloc[train_index]
    test_set = west_ph.iloc[test_index]
    rf_wp.fit(train_set[features_wp], train_set.rating)

    preds = rf_wp.predict(test_set[features_wp])
    rmse_wp[i] = root_mean_squared_error(test_set.rating, preds)
    i+=1

np.mean(rmse_wp)
# Out:
# np.float64(0.5078397461481556)

# %%
score_df = pd.DataFrame({'feature': features_wp,
                            'importance_score': rf_wp.feature_importances_})
score_df.sort_values('importance_score', ascending = False, inplace = True)
score_df.head(10)
# Out:
#                      feature  importance_score
# 2                   latitude          0.134554
# 1                  longitude          0.120944
# 0                    reviews          0.115511
# 5          Education Level %          0.112408
# 4                    % Black          0.110100
# 3               photos_count          0.091860
# 20      Fast food restaurant          0.084980
# 6   Foreign Born Immigrant %          0.071592
# 29            Pizza delivery          0.057203
# 27        Mexican restaurant          0.025578

# %%
features_wp
# Out:
# ['reviews',
#  'longitude',
#  'latitude',
#  'photos_count',
#  'Afghan restaurant',
#  'African restaurant',
#  'American restaurant',
#  'Asian fusion restaurant',
#  'Asian restaurant',
#  'Association / Organization',
#  'Bagel shop',
#  'Bakery',
#  'Bar',
#  'Bar & grill',
#  'Brazilian restaurant',
#  'Breakfast restaurant',
#  'Brunch restaurant',
#  'Bubble tea store',
#  'Cafe',
#  'Cafeteria',
#  'Cambodian restaurant',
#  'Caribbean restaurant',
#  'Cheesesteak restaurant',
#  'Chicken restaurant',
#  'Chicken wings restaurant',
#  'Chinese restaurant',
#  'Chinese takeaway',
#  'Cocktail bar',
#  'Coffee shop',
#  'Colombian restaurant',
#  'Convenience store',
#  'Creperie',
#  'Deli',
#  'Dessert shop',
#  'Dim sum restaurant',
#  'Diner',
#  'Dominican restaurant',
#  'Donut shop',
#  'Eritrean restaurant',
#  'Ethiopian restaurant',
#  'Falafel restaurant',
#  'Fast food restaurant',
#  'Fish & chips restaurant',
#  'French restaurant',
#  'Fried chicken takeaway',
#  'Gastropub',
#  'Greek restaurant',
#  'Grill',
#  'Halal restaurant',
#  'Health food restaurant',
#  'Hoagie restaurant',
#  'Ice cream shop',
#  'Indian restaurant',
#  'Indonesian restaurant',
#  'Irish pub',
#  'Israeli restaurant',
#  'Italian restaurant',
#  'Jamaican restaurant',
#  'Japanese restaurant',
#  'Korean restaurant',
#  'Latin American restaurant',
#  'Liquor store',
#  'Market',
#  'Mediterranean restaurant',
#  'Mexican restaurant',
#  'Middle Eastern restaurant',
#  'Organic restaurant',
#  'Pennsylvania Dutch restaurant',
#  'Pho restaurant',
#  'Pizza Takeout',
#  'Pizza delivery',
#  'Pizza restaurant',
#  'Polish restaurant',
#  'Pretzel store',
#  'Pub',
#  'Puerto Rican restaurant',
#  'Ramen restaurant',
#  'Restaurant',
#  'Salad shop',
#  'Salvadoran restaurant',
#  'Sandwich shop',
#  'Seafood restaurant',
#  'Sichuan restaurant',
#  'Soul food restaurant',
#  'Southern Italian restaurant',
#  'Sports bar',
#  'Taco restaurant',
#  'Takeout Restaurant',
#  'Tex-Mex restaurant',
#  'Thai restaurant',
#  'Traditional American restaurant',
#  'Vegan restaurant',
#  'Vegetarian restaurant',
#  'Vietnamese restaurant',
#  'West African restaurant']

# %%
data = pd.concat([rd_train, pd.get_dummies(rd_train['type'])], axis = 1)

features_wp = features_wp[:4] + data.columns[52:].tolist()

# %% [markdown]
# The best model that we have for "West Philadelphia" yet remains (general)'k-neighbors' regression with geospatial, 'reviews', and 'photos_count' features plus cuisine types. The CV avg. RMSE in ratings here is about 0.45. Let us see whether we can improve on this by the manual clustering we've promised.

# %%
#a function for obtaining the errors of the predictions made by an inputted model
def get_errs(model, features, data, bor, kfold):

    errs = np.array([])
    indices = np.array([])
    

    
    if bor is not None:
        for train_index, test_index in kfold.split(data, data.borough):
            train_set = data.iloc[train_index]
            test_set = data.iloc[test_index]
            model.fit(train_set[features], train_set.rating)

            test_set_bor = test_set[test_set.borough == bor]
            bor_test = test_set_bor.index.to_numpy()
            preds = model.predict(test_set_bor[features])
    
            diff = test_set_bor.rating - preds
            errs = np.concatenate((errs, np.abs(diff)))
            indices = np.concatenate((indices, bor_test))
        return errs, indices
    else:
        for train_index, test_index in kfold.split(data):
            train_set = data.iloc[train_index]
            test_set = data.iloc[test_index]
            model.fit(train_set[features], train_set.rating)
            preds = model.predict(test_set[features])
            index = test_set.index.to_numpy()

            diff = test_set.rating - preds
            errs = np.concatenate((errs, np.abs(diff)))
            indices = np.concatenate((indices, index))
        return errs, indices

# %% [markdown]
# Now we have the first step of the clustering algorithm.

# %%
#apply 'get_errs' with the best model
knn_wp =Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsRegressor(8))])
        
   
errs, indices = get_errs(knn_wp, features_wp, data, 'West Philadelphia', kfold)
# Out:
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(

# %%
np.sum((errs > 0.5))
# Out:
# np.int64(30)

# %%
#a function that assigns binary class labels to unacceptable errors and acceptable errors
def assign_class(data, bor, indices, errs, thresh):
    if bor is not None:
        data = data[data.borough == bor]
    
    data.loc[indices, 'Errors'] = errs #assign error values to the dataframe
    #classify large errors
    data['Class'] = data['Errors'].map(lambda x: x > thresh).astype(int)
    return data


#apply 'assign_class' to west philly
wp = assign_class(data, 'West Philadelphia', indices, errs, thresh = 0.5)
# Out:
# /var/folders/3j/bbm3n5gj58xg3wkn3ngyvyrm0000gn/T/ipykernel_76077/1468260896.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.loc[indices, 'Errors'] = errs #assign error values to the dataframe
# /var/folders/3j/bbm3n5gj58xg3wkn3ngyvyrm0000gn/T/ipykernel_76077/1468260896.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Class'] = data['Errors'].map(lambda x: x > thresh).astype(int)

# %%
features
# Out:
# ['latitude',
#  'longitude',
#  'photos_count',
#  'reviews',
#  'Median Household Income',
#  'Education Level %',
#  '% Black',
#  '% Hispanic/Latino',
#  'Foreign Born Immigrant %',
#  'Median Age']

# %% [markdown]
# Now that we have classified the large errors, we attempt decision tree classification to locate them by feature description. For the latter, we will use all available features.

# %%
#gather all features for the classification
class_features = features + ['Total Population', 'Poverty Rate %', '% White', '% Asian', 'Neighborhood Turnover %'] + features_wp[4:]

# %%
#import modules necessary for decision tree classification 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

from tree_helpers import SkNode, create_sk_nodes #tree_helpers is a Python file that organizes the nodes of a decision tree and returns the feature constraints of the leaf nodes
from sklearn.metrics import precision_score, recall_score

# %%
wp.loc[wp.Class == 1]
# Out:
#                                                   name   site  \
# 28                                          CM Chicken   True
# 75                             Kabobeesh Pizza & Grill   True
# 91                                    Papa Johns Pizza   True
# 104                                       Fresh Donuts   True
# 147                                            El Taco   True
# 183                                      Cucina Zapata  False
# 197                     Raising Cane's Chicken Fingers   True
# 219                             Chipotle Mexican Grill   True
# 242                                 ASAD’S HOT CHICKEN   True
# 299                                             Dahlak   True
# 324                                        Amsale Cafe   True
# 325                          Popeyes Louisiana Kitchen   True
# 329                                       Pete's Pizza   True
# 337                                        Royal Pizza   True
# 365                             Chipotle Mexican Grill   True
# 433                             Tropical Smoothie Cafe   True
# 454                                         McDonald's   True
# 511                                          Mood Cafe  False
# 514                                 Asad's Hot Chicken   True
# 517                                       Jimmy John's   True
# 524                                         Schmear It   True
# 584                                                KFC   True
# 596                                               Wawa   True
# 599                                        Sultan Cafe   True
# 665                                    Green Line Cafe   True
# 783                                         D.P. Dough   True
# 800                                                KFC   True
# 822  Naz's Halal Food - Fairmount | Pick Up & Deliv...   True
# 850                                    Shalom Pizzeria   True
# 944                                       Pete's Pizza   True
#
#                                               subtypes      category  \
# 28                      Chicken restaurant, Restaurant   restaurants
# 75                                    Pizza restaurant   restaurants
# 91                                    Pizza restaurant   restaurants
# 104                   Donut shop, Breakfast restaurant    Donut shop
# 147  Mexican restaurant, Burrito restaurant, Taco r...   restaurants
# 183                                 Mexican restaurant   restaurants
# 197  Fast food restaurant, American restaurant, Chi...   restaurants
# 219  Mexican restaurant, Caterer, Fast food restaurant   restaurants
# 242                               Fast food restaurant   restaurants
# 299  Eritrean restaurant, Bar, Ethiopian restaurant...   restaurants
# 324                               Ethiopian restaurant   restaurants
# 325  Chicken restaurant, Cajun restaurant, Fast foo...   restaurants
# 329  Pizza restaurant, Italian restaurant, Takeout ...   restaurants
# 337                                   Pizza restaurant   restaurants
# 365  Mexican restaurant, Caterer, Fast food restaurant   restaurants
# 433  Restaurant, Breakfast restaurant, Cafe, Fast f...    Juice shop
# 454  Fast food restaurant, Breakfast restaurant, Co...   restaurants
# 511  Indian restaurant, Cafe, Dessert shop, Restaurant   restaurants
# 514                               Fast food restaurant   restaurants
# 517  Sandwich shop, Caterer, Fast food restaurant, ...   restaurants
# 524                   Bagel shop, Breakfast restaurant    Bagel shop
# 584           Chicken restaurant, Fast food restaurant   restaurants
# 596  Fast food restaurant, Breakfast restaurant, Ca...   restaurants
# 599                                   Halal restaurant   restaurants
# 665                                  Coffee shop, Cafe  coffee shops
# 783                       Pizza restaurant, Restaurant   restaurants
# 800           Chicken restaurant, Fast food restaurant   restaurants
# 822                                   Halal restaurant   restaurants
# 850  Pizza restaurant, Dairy, Falafel restaurant, F...   restaurants
# 944              Pizza restaurant, Delivery Restaurant   restaurants
#
#                      type  phone                                 full_address  \
# 28     Chicken restaurant   True     3180 Chestnut St, Philadelphia, PA 19104
# 75       Pizza restaurant   True     5206 Chestnut St, Philadelphia, PA 19139
# 91       Pizza restaurant   True        104 S 40th St, Philadelphia, PA 19104
# 104            Donut shop   True   3914 Lancaster Ave, Philadelphia, PA 19104
# 147    Mexican restaurant   True    3233 Powelton Ave, Philadelphia, PA 19104
# 183    Mexican restaurant  False       3101 Ludlow St, Philadelphia, PA 19104
# 197  Fast food restaurant   True       3925 Walnut St, Philadelphia, PA 19104
# 219    Mexican restaurant   True       3925 Walnut St, Philadelphia, PA 19104
# 242  Fast food restaurant   True    4627 Woodland Ave, Philadelphia, PA 19143
# 299   Eritrean restaurant   True   4708 Baltimore Ave, Philadelphia, PA 19143
# 324  Ethiopian restaurant   True       4817 Walnut St, Philadelphia, PA 19139
# 325    Chicken restaurant   True     4160 Monument Rd, Philadelphia, PA 19131
# 329      Pizza restaurant   True       1913 N 54th St, Philadelphia, PA 19131
# 337      Pizza restaurant   True   4200 Baltimore Ave, Philadelphia, PA 19104
# 365    Mexican restaurant   True   3400 Lancaster Ave, Philadelphia, PA 19104
# 433            Restaurant   True     3737 Chestnut St, Philadelphia, PA 19104
# 454  Fast food restaurant   True       3935 Walnut St, Philadelphia, PA 19104
# 511     Indian restaurant   True   4618 Baltimore Ave, Philadelphia, PA 19143
# 514  Fast food restaurant   True         16 S 40th St, Philadelphia, PA 19104
# 517         Sandwich shop   True    3601 Market St #5, Philadelphia, PA 19104
# 524            Bagel shop   True    3601 Market St #5, Philadelphia, PA 19104
# 584    Chicken restaurant   True   6114 Lancaster Ave, Philadelphia, PA 19151
# 596  Fast food restaurant   True  3724-3744 Spruce St, Philadelphia, PA 19104
# 599      Halal restaurant   True       4501 Walnut St, Philadelphia, PA 19139
# 665           Coffee shop   True   3649 Lancaster Ave, Philadelphia, PA 19104
# 783      Pizza restaurant   True    3235 Powelton Ave, Philadelphia, PA 19104
# 800    Chicken restaurant   True   5700 Baltimore Ave, Philadelphia, PA 19143
# 822      Halal restaurant   True   3300 Fairmount Ave, Philadelphia, PA 19104
# 850      Pizza restaurant   True   7598 Haverford Ave, Philadelphia, PA 19151
# 944      Pizza restaurant   True   5158 Haverford Ave, Philadelphia, PA 19139
#
#                borough               street  postal_code  ...  \
# 28   West Philadelphia     3180 Chestnut St      19104.0  ...
# 75   West Philadelphia     5206 Chestnut St      19139.0  ...
# 91   West Philadelphia        104 S 40th St      19104.0  ...
# 104  West Philadelphia   3914 Lancaster Ave      19104.0  ...
# 147  West Philadelphia    3233 Powelton Ave      19104.0  ...
# 183  West Philadelphia       3101 Ludlow St      19104.0  ...
# 197  West Philadelphia       3925 Walnut St      19104.0  ...
# 219  West Philadelphia       3925 Walnut St      19104.0  ...
# 242  West Philadelphia    4627 Woodland Ave      19143.0  ...
# 299  West Philadelphia   4708 Baltimore Ave      19143.0  ...
# 324  West Philadelphia       4817 Walnut St      19139.0  ...
# 325  West Philadelphia     4160 Monument Rd      19131.0  ...
# 329  West Philadelphia       1913 N 54th St      19131.0  ...
# 337  West Philadelphia   4200 Baltimore Ave      19104.0  ...
# 365  West Philadelphia   3400 Lancaster Ave      19104.0  ...
# 433  West Philadelphia     3737 Chestnut St      19104.0  ...
# 454  West Philadelphia       3935 Walnut St      19104.0  ...
# 511  West Philadelphia   4618 Baltimore Ave      19143.0  ...
# 514  West Philadelphia         16 S 40th St      19104.0  ...
# 517  West Philadelphia    3601 Market St #5      19104.0  ...
# 524  West Philadelphia    3601 Market St #5      19104.0  ...
# 584  West Philadelphia   6114 Lancaster Ave      19151.0  ...
# 596  West Philadelphia  3724-3744 Spruce St      19104.0  ...
# 599  West Philadelphia       4501 Walnut St      19139.0  ...
# 665  West Philadelphia   3649 Lancaster Ave      19104.0  ...
# 783  West Philadelphia    3235 Powelton Ave      19104.0  ...
# 800  West Philadelphia   5700 Baltimore Ave      19143.0  ...
# 822  West Philadelphia   3300 Fairmount Ave      19104.0  ...
# 850  West Philadelphia   7598 Haverford Ave      19151.0  ...
# 944  West Philadelphia   5158 Haverford Ave      19139.0  ...
#
#      Takeout Restaurant  Tex-Mex restaurant Thai restaurant  \
# 28                False               False           False
# 75                False               False           False
# 91                False               False           False
# 104               False               False           False
# 147               False               False           False
# 183               False               False           False
# 197               False               False           False
# 219               False               False           False
# 242               False               False           False
# 299               False               False           False
# 324               False               False           False
# 325               False               False           False
# 329               False               False           False
# 337               False               False           False
# 365               False               False           False
# 433               False               False           False
# 454               False               False           False
# 511               False               False           False
# 514               False               False           False
# 517               False               False           False
# 524               False               False           False
# 584               False               False           False
# 596               False               False           False
# 599               False               False           False
# 665               False               False           False
# 783               False               False           False
# 800               False               False           False
# 822               False               False           False
# 850               False               False           False
# 944               False               False           False
#
#      Traditional American restaurant  Vegan restaurant Vegetarian restaurant  \
# 28                             False             False                 False
# 75                             False             False                 False
# 91                             False             False                 False
# 104                            False             False                 False
# 147                            False             False                 False
# 183                            False             False                 False
# 197                            False             False                 False
# 219                            False             False                 False
# 242                            False             False                 False
# 299                            False             False                 False
# 324                            False             False                 False
# 325                            False             False                 False
# 329                            False             False                 False
# 337                            False             False                 False
# 365                            False             False                 False
# 433                            False             False                 False
# 454                            False             False                 False
# 511                            False             False                 False
# 514                            False             False                 False
# 517                            False             False                 False
# 524                            False             False                 False
# 584                            False             False                 False
# 596                            False             False                 False
# 599                            False             False                 False
# 665                            False             False                 False
# 783                            False             False                 False
# 800                            False             False                 False
# 822                            False             False                 False
# 850                            False             False                 False
# 944                            False             False                 False
#
#      Vietnamese restaurant  West African restaurant  Errors  Class
# 28                   False                    False  0.8500      1
# 75                   False                    False  0.6000      1
# 91                   False                    False  0.9250      1
# 104                  False                    False  0.5875      1
# 147                  False                    False  0.5375      1
# 183                  False                    False  0.9625      1
# 197                  False                    False  0.5750      1
# 219                  False                    False  0.8125      1
# 242                  False                    False  1.4625      1
# 299                  False                    False  0.6125      1
# 324                  False                    False  0.6250      1
# 325                  False                    False  0.6875      1
# 329                  False                    False  1.0375      1
# 337                  False                    False  0.6750      1
# 365                  False                    False  1.0750      1
# 433                  False                    False  0.5750      1
# 454                  False                    False  0.5125      1
# 511                  False                    False  0.6500      1
# 514                  False                    False  1.2625      1
# 517                  False                    False  0.7875      1
# 524                  False                    False  0.5250      1
# 584                  False                    False  0.6250      1
# 596                  False                    False  0.6625      1
# 599                  False                    False  0.5875      1
# 665                  False                    False  0.5750      1
# 783                  False                    False  0.7250      1
# 800                  False                    False  0.6500      1
# 822                  False                    False  1.0125      1
# 850                  False                    False  0.6125      1
# 944                  False                    False  0.9000      1
#
# [30 rows x 145 columns]

# %%
#we write the classification algorithm as a class
class LE_Class():
    def __init__(self, class_features):
        self.features = class_features
        l = len(class_features)
        self.feat_imp = pd.DataFrame({'features': class_features, 'importance score': l*[0]})
        self.tree = None
        self.prec = 0
        self.recall = 0

    def fit(self, X):
        self.tree = DecisionTreeClassifier(
            min_samples_leaf = 5, # minimum number of samples in each leaf, to prevent overfitting
            random_state= 216)

        self.tree.fit(X[self.features], X['Class'])
        preds = self.tree.predict(X[self.features])
        self.prec = np.round(precision_score(X['Class'], preds), 4)
        self.recall = np.round(recall_score(X['Class'], preds), 4)

        self.feat_imp = pd.DataFrame({'features': class_features, 'importance score': self.tree.feature_importances_}).sort_values(
            'importance score', ascending = False)

# %%
#apply the classification to west philly data in class-labeled form
wp_le = LE_Class(class_features)
wp_le.fit(wp)
nodes = create_sk_nodes(wp_le.tree)

print(wp_le.prec)
print(wp_le.recall)
print(wp_le.feat_imp.head(10))
# Out:
# 0.75
# 0.9
#                             features  importance score
# 1                          longitude          0.338381
# 3                            reviews          0.180635
# 52              Fast food restaurant          0.131541
# 2                       photos_count          0.110872
# 8           Foreign Born Immigrant %          0.089437
# 0                           latitude          0.082086
# 82                  Pizza restaurant          0.067048
# 101  Traditional American restaurant          0.000000
# 102                 Vegan restaurant          0.000000
# 76         Middle Eastern restaurant          0.000000

# %% [markdown]
# As the next step, we extract the classification rubric provided by LE_Class, so that we can locate the corresponding cluster in the test dataset.

# %%
#a function for obtaining the Cartesian description for the data subsets corresponding to the leaf nodes
def get_subsets(nodes):
    #collect the coordinate constraints implicated for each leaf node
    endpts = {}
    i=0
    for node in nodes.values():
        if (node.is_leaf) and (node.prediction == 1):
            endpts[i] = node.get_constraints()
            i += 1
    num_subsets = len(endpts)

    #rearrange to the corresponding Cartesian product of coordinate sets for each leaf
    subsets = {key: [] for key in range(num_subsets)}
    i = 0
    for coord_bds in endpts.values():
        for j in range(len(coord_bds[0])):
            list = [coord_bds[0][j], coord_bds[1][j]]
            subsets[i].append(list)
        i += 1
    return subsets

subsets = get_subsets(nodes)
num_subsets = len(subsets)

#locate the cluster within the dataframe
def def_cluster(data, subsets, class_features):
    cluster = {}
    feature_num = len(class_features)


    for i in range(num_subsets):
        cluster[i] = data
        for j in range(feature_num):
            feature = class_features[j]
            cluster[i] = cluster[i].loc[(cluster[i][feature] > subsets[i][j][0]) &
                                 (cluster[i][feature] < subsets[i][j][1])]

    whole = pd.DataFrame({})
    for i in range(num_subsets):
        whole = pd.concat([whole, cluster[i]])
    return whole

whole = def_cluster(wp, subsets, class_features)
whole
# Out:
#                                                   name   site  \
# 329                                       Pete's Pizza   True
# 809                                     Larry's Steaks   True
# 812                               Little Caesars Pizza   True
# 850                                    Shalom Pizzeria   True
# 944                                       Pete's Pizza   True
# 46                               Class of 1920 Commons   True
# 91                                    Papa Johns Pizza   True
# 219                             Chipotle Mexican Grill   True
# 324                                        Amsale Cafe   True
# 337                                        Royal Pizza   True
# 517                                       Jimmy John's   True
# 524                                         Schmear It   True
# 599                                        Sultan Cafe   True
# 299                                             Dahlak   True
# 312                             Salt & Pepper Deli III   True
# 433                             Tropical Smoothie Cafe   True
# 511                                          Mood Cafe  False
# 765                                     Queen of Sheba   True
# 71                                                Wawa   True
# 197                     Raising Cane's Chicken Fingers   True
# 242                                 ASAD’S HOT CHICKEN   True
# 454                                         McDonald's   True
# 514                                 Asad's Hot Chicken   True
# 596                                               Wawa   True
# 104                                       Fresh Donuts   True
# 325                          Popeyes Louisiana Kitchen   True
# 493                                Crown Fried Chicken  False
# 505                                      Chris's Pizza  False
# 665                                    Green Line Cafe   True
# 28                                          CM Chicken   True
# 147                                            El Taco   True
# 183                                      Cucina Zapata  False
# 365                             Chipotle Mexican Grill   True
# 670                     Lascala's Fire University City   True
# 783                                         D.P. Dough   True
# 822  Naz's Halal Food - Fairmount | Pick Up & Deliv...   True
#
#                                               subtypes      category  \
# 329  Pizza restaurant, Italian restaurant, Takeout ...   restaurants
# 809  Pizza restaurant, Cheesesteak restaurant, Fast...   restaurants
# 812  Pizza restaurant, Fast food restaurant, Pizza ...   restaurants
# 850  Pizza restaurant, Dairy, Falafel restaurant, F...   restaurants
# 944              Pizza restaurant, Delivery Restaurant   restaurants
# 46                  Restaurant, Coffee shop, Cafeteria     Cafeteria
# 91                                    Pizza restaurant   restaurants
# 219  Mexican restaurant, Caterer, Fast food restaurant   restaurants
# 324                               Ethiopian restaurant   restaurants
# 337                                   Pizza restaurant   restaurants
# 517  Sandwich shop, Caterer, Fast food restaurant, ...   restaurants
# 524                   Bagel shop, Breakfast restaurant    Bagel shop
# 599                                   Halal restaurant   restaurants
# 299  Eritrean restaurant, Bar, Ethiopian restaurant...   restaurants
# 312                     Restaurant, Liquor store, Deli          Deli
# 433  Restaurant, Breakfast restaurant, Cafe, Fast f...    Juice shop
# 511  Indian restaurant, Cafe, Dessert shop, Restaurant   restaurants
# 765                          Ethiopian restaurant, Bar   restaurants
# 71   Fast food restaurant, Breakfast restaurant, Ca...   restaurants
# 197  Fast food restaurant, American restaurant, Chi...   restaurants
# 242                               Fast food restaurant   restaurants
# 454  Fast food restaurant, Breakfast restaurant, Co...   restaurants
# 514                               Fast food restaurant   restaurants
# 596  Fast food restaurant, Breakfast restaurant, Ca...   restaurants
# 104                   Donut shop, Breakfast restaurant    Donut shop
# 325  Chicken restaurant, Cajun restaurant, Fast foo...   restaurants
# 493           Chicken restaurant, Fast food restaurant   restaurants
# 505                                   Pizza restaurant   restaurants
# 665                                  Coffee shop, Cafe  coffee shops
# 28                      Chicken restaurant, Restaurant   restaurants
# 147  Mexican restaurant, Burrito restaurant, Taco r...   restaurants
# 183                                 Mexican restaurant   restaurants
# 365  Mexican restaurant, Caterer, Fast food restaurant   restaurants
# 670                     Restaurant, Italian restaurant   restaurants
# 783                       Pizza restaurant, Restaurant   restaurants
# 822                                   Halal restaurant   restaurants
#
#                      type  phone                                 full_address  \
# 329      Pizza restaurant   True       1913 N 54th St, Philadelphia, PA 19131
# 809      Pizza restaurant   True       2459 N 54th St, Philadelphia, PA 19131
# 812      Pizza restaurant   True   5901 Lancaster Ave, Philadelphia, PA 19151
# 850      Pizza restaurant   True   7598 Haverford Ave, Philadelphia, PA 19151
# 944      Pizza restaurant   True   5158 Haverford Ave, Philadelphia, PA 19139
# 46             Restaurant   True     3800 Locust Walk, Philadelphia, PA 19104
# 91       Pizza restaurant   True        104 S 40th St, Philadelphia, PA 19104
# 219    Mexican restaurant   True       3925 Walnut St, Philadelphia, PA 19104
# 324  Ethiopian restaurant   True       4817 Walnut St, Philadelphia, PA 19139
# 337      Pizza restaurant   True   4200 Baltimore Ave, Philadelphia, PA 19104
# 517         Sandwich shop   True    3601 Market St #5, Philadelphia, PA 19104
# 524            Bagel shop   True    3601 Market St #5, Philadelphia, PA 19104
# 599      Halal restaurant   True       4501 Walnut St, Philadelphia, PA 19139
# 299   Eritrean restaurant   True   4708 Baltimore Ave, Philadelphia, PA 19143
# 312            Restaurant   True       1102 S 47th St, Philadelphia, PA 19143
# 433            Restaurant   True     3737 Chestnut St, Philadelphia, PA 19104
# 511     Indian restaurant   True   4618 Baltimore Ave, Philadelphia, PA 19143
# 765  Ethiopian restaurant   True   4511 Baltimore Ave, Philadelphia, PA 19143
# 71   Fast food restaurant   True     3604 Chestnut St, Philadelphia, PA 19104
# 197  Fast food restaurant   True       3925 Walnut St, Philadelphia, PA 19104
# 242  Fast food restaurant   True    4627 Woodland Ave, Philadelphia, PA 19143
# 454  Fast food restaurant   True       3935 Walnut St, Philadelphia, PA 19104
# 514  Fast food restaurant   True         16 S 40th St, Philadelphia, PA 19104
# 596  Fast food restaurant   True  3724-3744 Spruce St, Philadelphia, PA 19104
# 104            Donut shop   True   3914 Lancaster Ave, Philadelphia, PA 19104
# 325    Chicken restaurant   True     4160 Monument Rd, Philadelphia, PA 19131
# 493    Chicken restaurant   True       4002 Market St, Philadelphia, PA 19104
# 505      Pizza restaurant   True   3701 Haverford Ave, Philadelphia, PA 19104
# 665           Coffee shop   True   3649 Lancaster Ave, Philadelphia, PA 19104
# 28     Chicken restaurant   True     3180 Chestnut St, Philadelphia, PA 19104
# 147    Mexican restaurant   True    3233 Powelton Ave, Philadelphia, PA 19104
# 183    Mexican restaurant  False       3101 Ludlow St, Philadelphia, PA 19104
# 365    Mexican restaurant   True   3400 Lancaster Ave, Philadelphia, PA 19104
# 670            Restaurant   True     3200 Chestnut St, Philadelphia, PA 19104
# 783      Pizza restaurant   True    3235 Powelton Ave, Philadelphia, PA 19104
# 822      Halal restaurant   True   3300 Fairmount Ave, Philadelphia, PA 19104
#
#                borough               street  postal_code  ...  \
# 329  West Philadelphia       1913 N 54th St      19131.0  ...
# 809  West Philadelphia       2459 N 54th St      19131.0  ...
# 812  West Philadelphia   5901 Lancaster Ave      19151.0  ...
# 850  West Philadelphia   7598 Haverford Ave      19151.0  ...
# 944  West Philadelphia   5158 Haverford Ave      19139.0  ...
# 46   West Philadelphia     3800 Locust Walk      19104.0  ...
# 91   West Philadelphia        104 S 40th St      19104.0  ...
# 219  West Philadelphia       3925 Walnut St      19104.0  ...
# 324  West Philadelphia       4817 Walnut St      19139.0  ...
# 337  West Philadelphia   4200 Baltimore Ave      19104.0  ...
# 517  West Philadelphia    3601 Market St #5      19104.0  ...
# 524  West Philadelphia    3601 Market St #5      19104.0  ...
# 599  West Philadelphia       4501 Walnut St      19139.0  ...
# 299  West Philadelphia   4708 Baltimore Ave      19143.0  ...
# 312  West Philadelphia       1102 S 47th St      19143.0  ...
# 433  West Philadelphia     3737 Chestnut St      19104.0  ...
# 511  West Philadelphia   4618 Baltimore Ave      19143.0  ...
# 765  West Philadelphia   4511 Baltimore Ave      19143.0  ...
# 71   West Philadelphia     3604 Chestnut St      19104.0  ...
# 197  West Philadelphia       3925 Walnut St      19104.0  ...
# 242  West Philadelphia    4627 Woodland Ave      19143.0  ...
# 454  West Philadelphia       3935 Walnut St      19104.0  ...
# 514  West Philadelphia         16 S 40th St      19104.0  ...
# 596  West Philadelphia  3724-3744 Spruce St      19104.0  ...
# 104  West Philadelphia   3914 Lancaster Ave      19104.0  ...
# 325  West Philadelphia     4160 Monument Rd      19131.0  ...
# 493  West Philadelphia       4002 Market St      19104.0  ...
# 505  West Philadelphia   3701 Haverford Ave      19104.0  ...
# 665  West Philadelphia   3649 Lancaster Ave      19104.0  ...
# 28   West Philadelphia     3180 Chestnut St      19104.0  ...
# 147  West Philadelphia    3233 Powelton Ave      19104.0  ...
# 183  West Philadelphia       3101 Ludlow St      19104.0  ...
# 365  West Philadelphia   3400 Lancaster Ave      19104.0  ...
# 670  West Philadelphia     3200 Chestnut St      19104.0  ...
# 783  West Philadelphia    3235 Powelton Ave      19104.0  ...
# 822  West Philadelphia   3300 Fairmount Ave      19104.0  ...
#
#      Takeout Restaurant  Tex-Mex restaurant Thai restaurant  \
# 329               False               False           False
# 809               False               False           False
# 812               False               False           False
# 850               False               False           False
# 944               False               False           False
# 46                False               False           False
# 91                False               False           False
# 219               False               False           False
# 324               False               False           False
# 337               False               False           False
# 517               False               False           False
# 524               False               False           False
# 599               False               False           False
# 299               False               False           False
# 312               False               False           False
# 433               False               False           False
# 511               False               False           False
# 765               False               False           False
# 71                False               False           False
# 197               False               False           False
# 242               False               False           False
# 454               False               False           False
# 514               False               False           False
# 596               False               False           False
# 104               False               False           False
# 325               False               False           False
# 493               False               False           False
# 505               False               False           False
# 665               False               False           False
# 28                False               False           False
# 147               False               False           False
# 183               False               False           False
# 365               False               False           False
# 670               False               False           False
# 783               False               False           False
# 822               False               False           False
#
#      Traditional American restaurant  Vegan restaurant Vegetarian restaurant  \
# 329                            False             False                 False
# 809                            False             False                 False
# 812                            False             False                 False
# 850                            False             False                 False
# 944                            False             False                 False
# 46                             False             False                 False
# 91                             False             False                 False
# 219                            False             False                 False
# 324                            False             False                 False
# 337                            False             False                 False
# 517                            False             False                 False
# 524                            False             False                 False
# 599                            False             False                 False
# 299                            False             False                 False
# 312                            False             False                 False
# 433                            False             False                 False
# 511                            False             False                 False
# 765                            False             False                 False
# 71                             False             False                 False
# 197                            False             False                 False
# 242                            False             False                 False
# 454                            False             False                 False
# 514                            False             False                 False
# 596                            False             False                 False
# 104                            False             False                 False
# 325                            False             False                 False
# 493                            False             False                 False
# 505                            False             False                 False
# 665                            False             False                 False
# 28                             False             False                 False
# 147                            False             False                 False
# 183                            False             False                 False
# 365                            False             False                 False
# 670                            False             False                 False
# 783                            False             False                 False
# 822                            False             False                 False
#
#      Vietnamese restaurant  West African restaurant  Errors  Class
# 329                  False                    False  1.0375      1
# 809                  False                    False  0.1250      0
# 812                  False                    False  0.5000      0
# 850                  False                    False  0.6125      1
# 944                  False                    False  0.9000      1
# 46                   False                    False  0.1500      0
# 91                   False                    False  0.9250      1
# 219                  False                    False  0.8125      1
# 324                  False                    False  0.6250      1
# 337                  False                    False  0.6750      1
# 517                  False                    False  0.7875      1
# 524                  False                    False  0.5250      1
# 599                  False                    False  0.5875      1
# 299                  False                    False  0.6125      1
# 312                  False                    False  0.1000      0
# 433                  False                    False  0.5750      1
# 511                  False                    False  0.6500      1
# 765                  False                    False  0.0625      0
# 71                   False                    False  0.1125      0
# 197                  False                    False  0.5750      1
# 242                  False                    False  1.4625      1
# 454                  False                    False  0.5125      1
# 514                  False                    False  1.2625      1
# 596                  False                    False  0.6625      1
# 104                  False                    False  0.5875      1
# 325                  False                    False  0.6875      1
# 493                  False                    False  0.1875      0
# 505                  False                    False  0.1250      0
# 665                  False                    False  0.5750      1
# 28                   False                    False  0.8500      1
# 147                  False                    False  0.5375      1
# 183                  False                    False  0.9625      1
# 365                  False                    False  1.0750      1
# 670                  False                    False  0.0250      0
# 783                  False                    False  0.7250      1
# 822                  False                    False  1.0125      1
#
# [36 rows x 145 columns]

# %% [markdown]
# We write functions that determine the rmse's on the 'good' and 'bad' subsets of the West Philly data.

# %%
def good_rmse(data, amb_data):

    index_to_remove = set(data.index.tolist())
    index = set(amb_data.index.tolist())
    index = index.difference(index_to_remove)
    index = [*index]


    squares = amb_data.loc[index, 'Errors']**2
    return np.sqrt(squares.mean())

good_rmse(whole, wp)
# Out:
# np.float64(0.27477854128961154)

# %%
def bad_rmse(data):

    squares = data['Errors']**2
    return np.sqrt(squares.mean())

bad_rmse(whole)
# Out:
# np.float64(0.7054660102844549)

# %% [markdown]
# It will be our objective to reduce the rmse on "whole" as much as possible.

# %% [markdown]
# ### Modeling on the New West Philly Cluster

# %%
wp_le.feat_imp.head(10)
# Out:
#                             features  importance score
# 1                          longitude          0.338381
# 3                            reviews          0.180635
# 52              Fast food restaurant          0.131541
# 2                       photos_count          0.110872
# 8           Foreign Born Immigrant %          0.089437
# 0                           latitude          0.082086
# 82                  Pizza restaurant          0.067048
# 101  Traditional American restaurant          0.000000
# 102                 Vegan restaurant          0.000000
# 76         Middle Eastern restaurant          0.000000

# %%
#pick the most significant features returned by LE_Class
w_feats = ['latitude', 'longitude', 'photos_count', 'Foreign Born Immigrant %', 'reviews', 'Pizza restaurant', 'Fast food restaurant']

# %%
num_k = 20

w_rmse = np.zeros((num_k, n_splits))

for k in range(num_k):
    knn_pipe = Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsRegressor(k+1))])
    i=0
    for train, test in kfold1.split(whole):
        train_set = whole.iloc[train]
        test_set = whole.iloc[test]

        knn_pipe.fit(train_set[w_feats[:-5] ], train_set.rating)
        preds = knn_pipe.predict(test_set[w_feats[:-5] ])
        w_rmse[k, i] = root_mean_squared_error(test_set.rating, preds)
        i += 1
w_rmse = np.mean(w_rmse, axis = 1)
min_k = np.argmin(w_rmse)
print(f"The best CV avg. RMSE is {w_rmse[min_k]: .3f}, occurring at k = {min_k +1}.")
# Out:
# The best CV avg. RMSE is  0.648, occurring at k = 6.

# %% [markdown]
# We try some other models with various combinations of features.

# %%
whole.type.value_counts()
# Out:
# type
# Pizza restaurant        10
# Fast food restaurant     5
# Restaurant               4
# Mexican restaurant       4
# Ethiopian restaurant     2
# Halal restaurant         2
# Chicken restaurant       2
# Falafel restaurant       1
# Sandwich shop            1
# Bagel shop               1
# Chinese restaurant       1
# Coffee shop              1
# Eritrean restaurant      1
# Indian restaurant        1
# Donut shop               1
# Name: count, dtype: int64

# %%
features
# Out:
# ['latitude',
#  'longitude',
#  'photos_count',
#  'reviews',
#  'Median Household Income',
#  'Education Level %',
#  '% Black',
#  '% Hispanic/Latino',
#  'Foreign Born Immigrant %',
#  'Median Age']

# %%
mlr = LinearRegression()
mlr_rmse = np.zeros(n_splits)
i=0 

for train, test in kfold1.split(whole):
    whole_tr = whole.iloc[train]
    whole_te = whole.iloc[test]
    mlr.fit(whole_tr[w_feats[:-5] + ['Poverty Rate %']], whole_tr.rating)
    preds = mlr.predict(whole_te[w_feats[:-5] + ['Poverty Rate %']])

    mlr_rmse[i] = root_mean_squared_error(whole_te.rating, preds)
    i += 1
np.mean(mlr_rmse)
# Out:
# np.float64(0.6260908604272559)

# %% [markdown]
# None of our models are providing much reduction in RMSE. We try a different perspective now.

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth = 7, random_state=59038)
w_rmse = np.zeros(n_splits)
i=0
for train, test in kfold1.split(whole):
    train_set = whole.iloc[train]
    test_set = whole.iloc[test]

    rf.fit(train_set[class_features], train_set.rating)
    preds = rf.predict(test_set[class_features])
    w_rmse[i] = root_mean_squared_error(test_set.rating, preds)
    i += 1

np.mean(w_rmse)
# Out:
# np.float64(0.6213705452827143)

# %%
rf.feature_importances_

pd.DataFrame({"features": class_features, 'importance scores': rf.feature_importances_}).sort_values("importance scores", ascending = False).head(10)
# Out:
#                    features  importance scores
# 2              photos_count           0.228796
# 10         Total Population           0.211553
# 1                 longitude           0.103237
# 0                  latitude           0.097645
# 3                   reviews           0.060217
# 9                Median Age           0.052146
# 11           Poverty Rate %           0.041185
# 7         % Hispanic/Latino           0.039690
# 4   Median Household Income           0.031021
# 5         Education Level %           0.029662

# %%
new_feats = ['latitude', 'longitude', 'reviews', 'photos_count', 'Median Age', 'Total Population', 'Poverty Rate %']

# %% [markdown]
# The point here was not to evaluate the predictive ability of random forest regression here, but rather to use it as a means of feature selection. We try those features with linear regression now.

# %%
mlr = LinearRegression()
mlr_rmse = np.zeros(n_splits)
i=0 

for train, test in kfold1.split(west_ph):
    west_ph_tr = west_ph.iloc[train]
    west_ph_te = west_ph.iloc[test]
    mlr.fit(west_ph_tr[new_feats], west_ph_tr.rating)
    preds = mlr.predict(west_ph_te[new_feats])
    for j in range(len(preds)):
        value = preds[j]
        if value >= 5.0:
            preds[j] = 5.0

    mlr_rmse[i] = root_mean_squared_error(west_ph_te.rating, preds)
    i += 1
np.mean(mlr_rmse)
# Out:
# np.float64(0.49509203828066434)

# %% [markdown]
# This is our best avg. CV RMSE yet, sizably better than the original value of 0.71.

# %% [markdown]
# We write the defining characteristics of the new cluster to file.

# %%
sub_index = [key for key in subsets.keys()]

cluster_df = pd.DataFrame(columns = ['origin', 'good_model', 'bad_model', 'class_features']+ sub_index)

cluster_df.loc[0] = [('West Philadelphia', '1'), ('8-neighbors (gen.)', features_wp), ('Linear Regression', new_feats), class_features] + [subset for subset in subsets.values()]

# %%
cluster_df.to_csv("../'Will It Restaurant?'/clusters.csv", index = False)
