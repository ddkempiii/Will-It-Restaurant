# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error

# %%
from cluster_fns import def_cluster
from ipynb.fs.defs.census_and_restaurant_data_withEDA import adjoin_census

# %%
rd_train = pd.read_csv("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/data_files/train_data_with_census.csv")
boroughs = np.sort(rd_train.borough.unique())

#adjoin census data
census_data = pd.read_csv("../'Will It Restaurant?'/data_files/census_data.csv")
rd_train = adjoin_census(rd_train, census_data)
#adjoin cuisine specificity
rd_train = pd.concat([rd_train, pd.get_dummies(rd_train.type)], axis = 1)

#load test data set and add cuisine specificity
rd_test = pd.read_csv("../'Will It Restaurant?'/data_files/test_data.csv")
rd_test = pd.concat([rd_test, pd.get_dummies(rd_test.type)], axis = 1)

#ensure that cuisine columns match for training and test set
miss_cuis = pd.DataFrame({cuis: len(rd_train)*[False] for cuis in rd_test.type.unique() if cuis not in rd_train.type.unique()})
rd_train = pd.concat([rd_train, miss_cuis], axis = 1)

miss_cuis = pd.DataFrame({cuis: len(rd_test)*[False] for cuis in rd_train.type.unique() if cuis not in rd_test.type.unique()})
rd_test = pd.concat([rd_test, miss_cuis], axis = 1)

# %%
#modify 'range' column for rd_test appropriately
rd_test['range'] = rd_test.range.fillna(0)
rd_test['range'] = rd_test.range.astype(int).astype(str)

# %%
rd_test.range.unique()
# Out:
# array(['1', '2', '3', '0', '4'], dtype=object)

# %%
rd_train.range.unique()
# Out:
# array(['2', '1', '3', '0', '2 stars', '3 stars', '4'], dtype=object)

# %%
rd_train
# Out:
#                                       name   site  \
# 0     The Legends of Seafood and Soul Food   True
# 1                                Fette Sau   True
# 2                                 Cafe Liz  False
# 3                    Plaza Pizza and Grill   True
# 4                         Little Fish BYOB   True
# ...                                    ...    ...
# 2383                           China House  False
# 2384                        Sabrina's Cafe   True
# 2385                         Dagwood's Pub   True
# 2386                               Malooga   True
# 2387                       Pastificio Deli   True
#
#                                                subtypes     category  \
# 0              Seafood restaurant, Soul food restaurant  restaurants
# 1     Restaurant, American restaurant, Barbecue rest...  restaurants
# 2                            Portuguese restaurant, Bar  restaurants
# 3     Pizza restaurant, Breakfast restaurant, Cheese...  restaurants
# 4                                    Seafood restaurant  restaurants
# ...                                                 ...          ...
# 2383            Chinese restaurant, Delivery Restaurant  restaurants
# 2384  Restaurant, Breakfast restaurant, Brunch resta...  restaurants
# 2385                                        Bar & grill  restaurants
# 2386  Middle Eastern restaurant, Falafel restaurant,...  restaurants
# 2387            Deli, Takeout Restaurant, Sandwich shop         Deli
#
#                            type  phone  \
# 0            Seafood restaurant   True
# 1                    Restaurant   True
# 2         Portuguese restaurant   True
# 3              Pizza restaurant   True
# 4            Seafood restaurant   True
# ...                         ...    ...
# 2383         Chinese restaurant   True
# 2384                 Restaurant   True
# 2385                Bar & grill   True
# 2386  Middle Eastern restaurant   True
# 2387                       Deli   True
#
#                                          full_address                 borough  \
# 0           5352 Woodland Ave, Philadelphia, PA 19143             Kingsessing
# 1          1208 Frankford Ave, Philadelphia, PA 19125                Fishtown
# 2          5437 N Lawrence St, Philadelphia, PA 19120          Olney-Oak Lane
# 3     1614 Cecil B. Moore Ave, Philadelphia, PA 19121      North Philadelphia
# 4                746 S 6th St, Philadelphia, PA 19147             Bella Vista
# ...                                               ...                     ...
# 2383    2015, 7141 Ogontz Ave, Philadelphia, PA 19138          Olney-Oak Lane
# 2384       1804 Callowhill St, Philadelphia, PA 19130             Center City
# 2385          4625 Linden Ave, Philadelphia, PA 19114  Northeast Philadelphia
# 2386          134 Chestnut St, Philadelphia, PA 19106        Center City East
# 2387          1528 Packer Ave, Philadelphia, PA 19145      South Philadelphia
#
#                        street  postal_code  ...  Rice restaurant  \
# 0           5352 Woodland Ave      19143.0  ...            False
# 1          1208 Frankford Ave      19125.0  ...            False
# 2          5437 N Lawrence St      19120.0  ...            False
# 3     1614 Cecil B. Moore Ave      19121.0  ...            False
# 4                746 S 6th St      19147.0  ...            False
# ...                       ...          ...  ...              ...
# 2383    2015, 7141 Ogontz Ave      19138.0  ...            False
# 2384       1804 Callowhill St      19130.0  ...            False
# 2385          4625 Linden Ave      19114.0  ...            False
# 2386          134 Chestnut St      19106.0  ...            False
# 2387          1528 Packer Ave      19145.0  ...            False
#
#       Family restaurant Jewish restaurant  Fusion restaurant  \
# 0                 False             False              False
# 1                 False             False              False
# 2                 False             False              False
# 3                 False             False              False
# 4                 False             False              False
# ...                 ...               ...                ...
# 2383              False             False              False
# 2384              False             False              False
# 2385              False             False              False
# 2386              False             False              False
# 2387              False             False              False
#
#       Tunisian restaurant Indian takeaway  Taiwanese restaurant  \
# 0                   False           False                 False
# 1                   False           False                 False
# 2                   False           False                 False
# 3                   False           False                 False
# 4                   False           False                 False
# ...                   ...             ...                   ...
# 2383                False           False                 False
# 2384                False           False                 False
# 2385                False           False                 False
# 2386                False           False                 False
# 2387                False           False                 False
#
#       Argentinian restaurant  Juice shop  Laotian restaurant
# 0                      False       False               False
# 1                      False       False               False
# 2                      False       False               False
# 3                      False       False               False
# 4                      False       False               False
# ...                      ...         ...                 ...
# 2383                   False       False               False
# 2384                   False       False               False
# 2385                   False       False               False
# 2386                   False       False               False
# 2387                   False       False               False
#
# [2388 rows x 234 columns]

# %%
rd_test
# Out:
#                          name  site  \
# 0                        Wawa  True
# 1     Otto's Taproom & Grille  True
# 2       Akira Ramen & Hibachi  True
# 3                Standard Tap  True
# 4    The Sidecar Bar & Grille  True
# ..                        ...   ...
# 592    NAM Vietnamese Kitchen  True
# 593            All Star Pizza  True
# 594  Bill's Breakfast & Lunch  True
# 595              Krush Lounge  True
# 596         Winnie's Manayunk  True
#
#                                               subtypes     category  \
# 0    Fast food restaurant, Breakfast restaurant, Ca...  restaurants
# 1                                      Restaurant, Bar  restaurants
# 2                                  Japanese restaurant  restaurants
# 3    Restaurant, Cocktail bar, New American restaur...         bars
# 4    Bar & grill, American restaurant, Bar, Gastrop...  restaurants
# ..                                                 ...          ...
# 592                              Vietnamese restaurant  restaurants
# 593              Pizza restaurant, Delivery Restaurant  restaurants
# 594  Restaurant, Breakfast restaurant, Brunch resta...  restaurants
# 595                                        Bar & grill  restaurants
# 596                 Restaurant, Bar, Brunch restaurant  restaurants
#
#                       type  phone  \
# 0     Fast food restaurant   True
# 1               Restaurant   True
# 2      Japanese restaurant   True
# 3               Restaurant   True
# 4              Bar & grill   True
# ..                     ...    ...
# 592  Vietnamese restaurant   True
# 593       Pizza restaurant   True
# 594             Restaurant   True
# 595            Bar & grill   True
# 596             Restaurant   True
#
#                                           full_address  \
# 0          6858 Rising Sun Ave, Philadelphia, PA 19111
# 1               1216 N 29th St, Philadelphia, PA 19121
# 2              7628 Castor Ave, Philadelphia, PA 19152
# 3                 901 N 2nd St, Philadelphia, PA 19123
# 4            2201 Christian St, Philadelphia, PA 19146
# ..                                                 ...
# 592  3816 Chestnut St Unit 8 Unit 8, Philadelphia, ...
# 593                 2345 Street Rd, Bensalem, PA 19020
# 594             1312 Sansom St, Philadelphia, PA 19107
# 595        6414 Rising Sun Ave, Philadelphia, PA 19111
# 596               4266 Main St, Philadelphia, PA 19127
#
#                     borough                          street  postal_code  ...  \
# 0    Northeast Philadelphia             6858 Rising Sun Ave      19111.0  ...
# 1        North Philadelphia                  1216 N 29th St      19121.0  ...
# 2    Northeast Philadelphia                 7628 Castor Ave      19152.0  ...
# 3        Northern Liberties                    901 N 2nd St      19123.0  ...
# 4     Southwest Center City               2201 Christian St      19146.0  ...
# ..                      ...                             ...          ...  ...
# 592       West Philadelphia  3816 Chestnut St Unit 8 Unit 8      19104.0  ...
# 593                Bensalem                  2345 Street Rd      19020.0  ...
# 594        Center City East                  1312 Sansom St      19107.0  ...
# 595  Northeast Philadelphia             6414 Rising Sun Ave      19111.0  ...
# 596     Roxborough-Manayunk                    4266 Main St      19127.0  ...
#
#      Amusement center  Ecuadorian restaurant Traditional American restaurant  \
# 0               False                  False                           False
# 1               False                  False                           False
# 2               False                  False                           False
# 3               False                  False                           False
# 4               False                  False                           False
# ..                ...                    ...                             ...
# 592             False                  False                           False
# 593             False                  False                           False
# 594             False                  False                           False
# 595             False                  False                           False
# 596             False                  False                           False
#
#      Fried chicken takeaway  Grill Cuban restaurant  Mobile caterer  \
# 0                     False  False            False           False
# 1                     False  False            False           False
# 2                     False  False            False           False
# 3                     False  False            False           False
# 4                     False  False            False           False
# ..                      ...    ...              ...             ...
# 592                   False  False            False           False
# 593                   False  False            False           False
# 594                   False  False            False           False
# 595                   False  False            False           False
# 596                   False  False            False           False
#
#      Event venue  Southeast Asian restaurant  Bubble tea store
# 0          False                       False             False
# 1          False                       False             False
# 2          False                       False             False
# 3          False                       False             False
# 4          False                       False             False
# ..           ...                         ...               ...
# 592        False                       False             False
# 593        False                       False             False
# 594        False                       False             False
# 595        False                       False             False
# 596        False                       False             False
#
# [597 rows x 234 columns]

# %% [markdown]
# ## Arrangement of Initial Model-Cluster Pairings

# %%
all_models = pd.read_csv("../'Will It Restaurant?'/initial_modeling/model_comparison(all_rests).csv")

# %%
all_models.rename(columns = {'Best k': 'Best k (geospatial, interact., cuis)', 'Best k.1': 'Best k (geospatial)', 'Best k.2': 'Best k (geospatial, bor)', 'Min. RMSE': 'CV Avg. RMSE.2'}, inplace = True)
all_models.index = boroughs
all_models.drop(labels = ['Northeast Philadelphia', 'West Philadelphia'], axis = 0, inplace = True)
all_models
# Out:
#                          Best k (geospatial, interact., cuis)  CV Avg. RMSE  \
# Allegheny West                                              5      0.272305
# Bella Vista                                                 5      0.265526
# Bensalem                                                    4      0.467987
# Center City                                                 5      0.351571
# Center City East                                            5      0.347562
# Chestnut Hill                                               2      0.271802
# East Germantown                                             5      0.409866
# East Kensington                                             5      0.228961
# East Passyunk Crossing                                      5      0.401182
# Elmwood Park                                                2      0.387735
# Essington                                                   1      0.430172
# Fairhill                                                    4      0.314775
# Fairmount                                                   5      0.340144
# Feltonville                                                 5      0.320448
# Fishtown                                                    5      0.358122
# Fox Chase                                                   5      0.344969
# Frankford                                                   5      0.363788
# Germantown                                                  4      0.334182
# Harrowgate                                                  5      0.235434
# Huntingdon Valley                                           1      0.050000
# Kingsessing                                                 3      0.259855
# Lester                                                      5      0.810000
# Lower Moyamensing                                           4      0.312910
# Manayunk                                                    1      0.566667
# Mount Airy                                                  5      0.360805
# Newbold                                                     4      0.326365
# Nicetown–Tioga                                              2      0.401555
# North Philadelphia                                          5      0.400819
# North Philadelphia East                                     3      0.377980
# Northern Liberties                                          5      0.293328
# Northwest Philadelphia                                      3      0.150000
# Ogontz                                                      4      0.473024
# Old City                                                    2      0.337500
# Olde Kensington                                             2      0.224358
# Olde Richmond                                               5      0.476397
# Olney-Oak Lane                                              3      0.370255
# Pennsport                                                   1      0.465837
# Port Richmond                                               5      0.362441
# Rittenhouse Square                                          5      0.233177
# Roxborough-Manayunk                                         5      0.376585
# Sharswood                                                   5      0.535000
# South Philadelphia                                          5      0.338424
# South Philadelphia East                                     2      0.262103
# Southwark                                                   1      0.280052
# Southwest Center City                                       4      0.397606
# Southwest Philadelphia                                      3      0.592029
# Stanton                                                     5      0.299700
# Stenton                                                     2      0.430397
# Strawberry Mansion                                          3      0.304338
# Tacony                                                      5      0.326540
# Unlabeled                                                   5      0.672701
# Whitman                                                     4      0.126098
#
#                          Best k (geospatial)  CV Avg. RMSE.1  \
# Allegheny West                            48        0.345464
# Bella Vista                               23        0.190454
# Bensalem                                  15        0.476567
# Center City                               18        0.327539
# Center City East                          47        0.339561
# Chestnut Hill                             38        0.301278
# East Germantown                           10        0.497392
# East Kensington                            3        0.189985
# East Passyunk Crossing                     7        0.304203
# Elmwood Park                              31        0.375245
# Essington                                  4        0.297082
# Fairhill                                  39        0.298265
# Fairmount                                  5        0.382793
# Feltonville                               23        0.363435
# Fishtown                                  40        0.343634
# Fox Chase                                  7        0.376628
# Frankford                                 25        0.356276
# Germantown                                35        0.405252
# Harrowgate                                39        0.274330
# Huntingdon Valley                          1        0.050000
# Kingsessing                               15        0.363267
# Lester                                     1        0.000000
# Lower Moyamensing                         27        0.304845
# Manayunk                                   1        0.633333
# Mount Airy                                48        0.370720
# Newbold                                   50        0.372811
# Nicetown–Tioga                             2        0.365739
# North Philadelphia                        20        0.444425
# North Philadelphia East                    6        0.460383
# Northern Liberties                        12        0.229207
# Northwest Philadelphia                    47        0.129787
# Ogontz                                    10        0.419979
# Old City                                   2        0.437500
# Olde Kensington                            5        0.190998
# Olde Richmond                              2        0.389667
# Olney-Oak Lane                            12        0.410625
# Pennsport                                  4        0.431683
# Port Richmond                              6        0.400876
# Rittenhouse Square                        12        0.190672
# Roxborough-Manayunk                        9        0.381251
# Sharswood                                  7        0.353571
# South Philadelphia                        48        0.415692
# South Philadelphia East                   43        0.343659
# Southwark                                 46        0.300686
# Southwest Center City                      2        0.439475
# Southwest Philadelphia                     5        0.429110
# Stanton                                   25        0.192129
# Stenton                                   49        0.434990
# Strawberry Mansion                         2        0.313042
# Tacony                                    34        0.353035
# Unlabeled                                  7        0.511635
# Whitman                                    5        0.252636
#
#                          Best k (geospatial, bor)  CV Avg. RMSE.2  \
# Allegheny West                                  8        0.360631
# Bella Vista                                     6        0.208949
# Bensalem                                        4        0.705114
# Center City                                    11        0.322179
# Center City East                               10        0.336999
# Chestnut Hill                                   1        0.276455
# East Germantown                                20        0.534539
# East Kensington                                 8        0.200562
# East Passyunk Crossing                          4        0.268043
# Elmwood Park                                   26        0.372289
# Essington                                       3        0.290785
# Fairhill                                       16        0.327784
# Fairmount                                      29        0.399280
# Feltonville                                    19        0.380509
# Fishtown                                       10        0.336775
# Fox Chase                                       4        0.347266
# Frankford                                      20        0.355891
# Germantown                                     18        0.404637
# Harrowgate                                      4        0.358774
# Huntingdon Valley                               0        1.000000
# Kingsessing                                    10        0.419377
# Lester                                          0        1.000000
# Lower Moyamensing                              11        0.345141
# Manayunk                                        0        1.000000
# Mount Airy                                      8        0.410427
# Newbold                                         5        0.352269
# Nicetown–Tioga                                  8        0.376706
# North Philadelphia                             54        0.428413
# North Philadelphia East                        36        0.484687
# Northern Liberties                              2        0.218482
# Northwest Philadelphia                          0        1.000000
# Ogontz                                         14        0.511431
# Old City                                        0        1.000000
# Olde Kensington                                 8        0.137539
# Olde Richmond                                   1        0.494507
# Olney-Oak Lane                                 27        0.423855
# Pennsport                                       2        0.384596
# Port Richmond                                   4        0.373389
# Rittenhouse Square                              9        0.195069
# Roxborough-Manayunk                             3        0.380567
# Sharswood                                       0        1.000000
# South Philadelphia                             48        0.419803
# South Philadelphia East                         4        0.342666
# Southwark                                      15        0.304511
# Southwest Center City                           2        0.413792
# Southwest Philadelphia                          5        0.465886
# Stanton                                         6        0.171132
# Stenton                                        24        0.438890
# Strawberry Mansion                             10        0.352466
# Tacony                                          9        0.399270
# Unlabeled                                       3        0.471317
# Whitman                                         4        0.244497
#
#                          Number of Restaurants
# Allegheny West                              22
# Bella Vista                                 33
# Bensalem                                     6
# Center City                                128
# Center City East                           212
# Chestnut Hill                               22
# East Germantown                             26
# East Kensington                             10
# East Passyunk Crossing                      26
# Elmwood Park                                35
# Essington                                    6
# Fairhill                                    23
# Fairmount                                   39
# Feltonville                                 30
# Fishtown                                    50
# Fox Chase                                   18
# Frankford                                   29
# Germantown                                  26
# Harrowgate                                   8
# Huntingdon Valley                            2
# Kingsessing                                 14
# Lester                                       2
# Lower Moyamensing                           15
# Manayunk                                     3
# Mount Airy                                  22
# Newbold                                     19
# Nicetown–Tioga                              21
# North Philadelphia                          92
# North Philadelphia East                     76
# Northern Liberties                          36
# Northwest Philadelphia                       2
# Ogontz                                      18
# Old City                                     4
# Olde Kensington                             10
# Olde Richmond                               13
# Olney-Oak Lane                              90
# Pennsport                                   18
# Port Richmond                               34
# Rittenhouse Square                          88
# Roxborough-Manayunk                        106
# Sharswood                                    4
# South Philadelphia                         127
# South Philadelphia East                     25
# Southwark                                   27
# Southwest Center City                       27
# Southwest Philadelphia                      42
# Stanton                                      8
# Stenton                                     32
# Strawberry Mansion                          18
# Tacony                                      17
# Unlabeled                                   44
# Whitman                                      7

# %%
#an algorithm that selects the best performing k-neighbors model among k < 21 from above or model with smallest k 
models = {}
i=0
for bor in all_models.index:
    k_s = all_models.iloc[i, [0,2,4]].values
    k_s = np.array([[k_s[0], 0], [k_s[1], 2], [k_s[2], 4]])
    k_val = k_s[:, 0]
    k_val = k_val[k_val != 0]
    #pick smallest error among k's less than 21
    if np.any(k_val <=20):
        k_s = [k for k in k_s if (k[0] <=20) & (k[0] > 0)]
        rm_ind = np.array([k[1] for k in k_s]) + 1
        drow = all_models.iloc[i, rm_ind].values
        min = np.argmin(drow)
        loc = int(rm_ind[min] - 1)
        k = all_models.iat[i, loc]


        models[bor] = [all_models.columns[loc], 'k= ' + str(k)]
    #pick smallest k if all k's exceed 20
    else:
        min = np.argmin(k_val)
        loc = int(k_s[min][1])
        k = k_val[min]

        models[bor] = [all_models.columns[loc], 'k= ' + str(k)]
        
    i +=1

models
# Out:
# {'Allegheny West': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Bella Vista': ['Best k (geospatial, bor)', 'k= 6'],
#  'Bensalem': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Center City': ['Best k (geospatial, bor)', 'k= 11'],
#  'Center City East': ['Best k (geospatial, bor)', 'k= 10'],
#  'Chestnut Hill': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'East Germantown': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'East Kensington': ['Best k (geospatial)', 'k= 3'],
#  'East Passyunk Crossing': ['Best k (geospatial, bor)', 'k= 4'],
#  'Elmwood Park': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Essington': ['Best k (geospatial, bor)', 'k= 3'],
#  'Fairhill': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Fairmount': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Feltonville': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Fishtown': ['Best k (geospatial, bor)', 'k= 10'],
#  'Fox Chase': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Frankford': ['Best k (geospatial, bor)', 'k= 20'],
#  'Germantown': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Harrowgate': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Huntingdon Valley': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Kingsessing': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Lester': ['Best k (geospatial)', 'k= 1'],
#  'Lower Moyamensing': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Manayunk': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Mount Airy': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Newbold': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Nicetown–Tioga': ['Best k (geospatial)', 'k= 2'],
#  'North Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'North Philadelphia East': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Northern Liberties': ['Best k (geospatial, bor)', 'k= 2'],
#  'Northwest Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Ogontz': ['Best k (geospatial)', 'k= 10'],
#  'Old City': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Olde Kensington': ['Best k (geospatial, bor)', 'k= 8'],
#  'Olde Richmond': ['Best k (geospatial)', 'k= 2'],
#  'Olney-Oak Lane': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Pennsport': ['Best k (geospatial, bor)', 'k= 2'],
#  'Port Richmond': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Rittenhouse Square': ['Best k (geospatial)', 'k= 12'],
#  'Roxborough-Manayunk': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Sharswood': ['Best k (geospatial)', 'k= 7'],
#  'South Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'South Philadelphia East': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Southwark': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Southwest Center City': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Southwest Philadelphia': ['Best k (geospatial)', 'k= 5'],
#  'Stanton': ['Best k (geospatial, bor)', 'k= 6'],
#  'Stenton': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Strawberry Mansion': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Tacony': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Unlabeled': ['Best k (geospatial, bor)', 'k= 3'],
#  'Whitman': ['Best k (geospatial, interact., cuis)', 'k= 4']}

# %% [markdown]
# ## Arrangement of Advanced Model-Cluster Pairings

# %%
#read in the cluster dataframe
from ast import literal_eval

def safest_literal_eval(x):
    #replace problematic substrings with acceptable strings arising from outside parameters of data
    if pd.isna(x):
        return x
    else:
        x = x.replace("np.float64", "")
        x = x.replace("(", "")
        x = x.replace(")", "")
        x = x.replace("-inf", "-123456789010") #to handle infinite endpoints, we assign a dummy value lying outside range of data
        x = x.replace("inf", '123456789010')
        #method for rendering list and number form of such styled as strings
        x = literal_eval(x)
        for j in range(len(x)):
            if x[j][0] == -123456789010:
                x[j][0] = -np.inf
            if x[j][1] == 123456789010:
                x[j][1] = np.inf

    

        return x
    
def safe_literal_eval(x):
    if pd.isna(x):
        return x
    else: 
        return literal_eval(x)
    

cluster_df = pd.read_csv("../'Will It Restaurant?'/cluster_modeling/clusters.csv")
cluster_df['origin'] = cluster_df['origin'].apply(literal_eval)
cluster_df['good_model'] = cluster_df['good_model'].apply(literal_eval)
cluster_df['bad_model'] = cluster_df['bad_model'].apply(safe_literal_eval)
cluster_df['class_features'] = cluster_df['class_features'].apply(safe_literal_eval)

cluster_df['0'] = cluster_df['0'].apply(safest_literal_eval)
cluster_df['1'] = cluster_df['1'].apply(safest_literal_eval)
cluster_df['2'] = cluster_df['2'].apply(safest_literal_eval)
cluster_df['3'] = cluster_df['3'].apply(safest_literal_eval)
cluster_df['4'] = cluster_df['4'].apply(safest_literal_eval)
cluster_df['5'] = cluster_df['5'].apply(safest_literal_eval)

# %%
cluster_df
# Out:
#                           origin  \
# 0         (West Philadelphia, 1)
# 1         (West Philadelphia, 2)
# 2         (West Philadelphia, 0)
# 3    (Northeast Philadelphia, 1)
# 4  (Northeast Philadelphia, 2-3)
# 5    (Northeast Philadelphia, 0)
#
#                                           good_model  \
# 0  (8-neighbors (gen.), [reviews, longitude, lati...
# 1  (17-neighbors (bor.), [reviews, Foreign Born I...
# 2  (Random Forest 5 (bor.), [latitude, longitude,...
# 3  (6-neighbors (gen.), [latitude, longitude, rev...
# 4  (14-neighbors (bor.), [latitude, longitude, re...
# 5  (5-neighbors (bor.), [latitude, longitude, rev...
#
#                                            bad_model  \
# 0  (Linear Regression, [latitude, longitude, revi...
# 1  (Linear Regression, [reviews, latitude, longit...
# 2                                                NaN
# 3  (5-neighbors, [Foreign Born Immigrant %, revie...
# 4                                                NaN
# 5                                                NaN
#
#                                       class_features  \
# 0  [latitude, longitude, photos_count, reviews, M...
# 1  [latitude, longitude, photos_count, reviews, M...
# 2                                                NaN
# 3  [latitude, longitude, reviews, photos_count, M...
# 4                                                NaN
# 5                                                NaN
#
#                                                    0  \
# 0  [[-inf, inf], [-inf, -75.21855545043945], [-in...
# 1  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    1  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, inf], [-inf, -75.25553512573242], [-in...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [238...
# 4                                                NaN
# 5                                                NaN
#
#                                                    2  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, 39.94808769226074], [-75.2555351257324...
# 2                                                NaN
# 3  [[-inf, inf], [-75.03024673461914, inf], [-inf...
# 4                                                NaN
# 5                                                NaN
#
#                                                    3  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[39.94808769226074, inf], [-75.25553512573242...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 4                                                NaN
# 5                                                NaN
#
#                                                    4  \
# 0  [[39.95686149597168, inf], [-75.21855545043945...
# 1                                                NaN
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.06171417236328], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    5
# 0  [[-inf, inf], [-75.19183731079102, inf], [-inf...
# 1                                                NaN
# 2                                                NaN
# 3  [[40.040489196777344, inf], [-inf, inf], [-inf...
# 4                                                NaN
# 5                                                NaN

# %% [markdown]
# ## Protocol for Application of Models and Clustering

# %% [markdown]
# ### Initial Clusters

# %%
#organize collection of feature subsets
cuis = rd_train.type.unique().tolist()
feats_gic = ['latitude', 'longitude', 'reviews', 'photos_count'] + cuis
feats_g = feats_gic[:2]

# %%
#instantiate the models to be used
def knn_pipe_var(k):
    knn_pipe = Pipeline([('scale', StandardScaler()), ('knn', KNeighborsRegressor(k))])
    return knn_pipe

mlr = LinearRegression()

def rf_var(feats):
    rf = RandomForestRegressor(max_depth = 5, random_state= 50492, max_features = len(feats))
    return rf

# %%
models
# Out:
# {'Allegheny West': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Bella Vista': ['Best k (geospatial, bor)', 'k= 6'],
#  'Bensalem': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Center City': ['Best k (geospatial, bor)', 'k= 11'],
#  'Center City East': ['Best k (geospatial, bor)', 'k= 10'],
#  'Chestnut Hill': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'East Germantown': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'East Kensington': ['Best k (geospatial)', 'k= 3'],
#  'East Passyunk Crossing': ['Best k (geospatial, bor)', 'k= 4'],
#  'Elmwood Park': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Essington': ['Best k (geospatial, bor)', 'k= 3'],
#  'Fairhill': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Fairmount': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Feltonville': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Fishtown': ['Best k (geospatial, bor)', 'k= 10'],
#  'Fox Chase': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Frankford': ['Best k (geospatial, bor)', 'k= 20'],
#  'Germantown': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Harrowgate': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Huntingdon Valley': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Kingsessing': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Lester': ['Best k (geospatial)', 'k= 1'],
#  'Lower Moyamensing': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Manayunk': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Mount Airy': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Newbold': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Nicetown–Tioga': ['Best k (geospatial)', 'k= 2'],
#  'North Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'North Philadelphia East': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Northern Liberties': ['Best k (geospatial, bor)', 'k= 2'],
#  'Northwest Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Ogontz': ['Best k (geospatial)', 'k= 10'],
#  'Old City': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Olde Kensington': ['Best k (geospatial, bor)', 'k= 8'],
#  'Olde Richmond': ['Best k (geospatial)', 'k= 2'],
#  'Olney-Oak Lane': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Pennsport': ['Best k (geospatial, bor)', 'k= 2'],
#  'Port Richmond': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Rittenhouse Square': ['Best k (geospatial)', 'k= 12'],
#  'Roxborough-Manayunk': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Sharswood': ['Best k (geospatial)', 'k= 7'],
#  'South Philadelphia': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'South Philadelphia East': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Southwark': ['Best k (geospatial, interact., cuis)', 'k= 1'],
#  'Southwest Center City': ['Best k (geospatial, interact., cuis)', 'k= 4'],
#  'Southwest Philadelphia': ['Best k (geospatial)', 'k= 5'],
#  'Stanton': ['Best k (geospatial, bor)', 'k= 6'],
#  'Stenton': ['Best k (geospatial, interact., cuis)', 'k= 2'],
#  'Strawberry Mansion': ['Best k (geospatial, interact., cuis)', 'k= 3'],
#  'Tacony': ['Best k (geospatial, interact., cuis)', 'k= 5'],
#  'Unlabeled': ['Best k (geospatial, bor)', 'k= 3'],
#  'Whitman': ['Best k (geospatial, interact., cuis)', 'k= 4']}

# %%
#for later convenience, we write the application of borough-specific regression as a class

class K_Bor():
    """A class for applying borough-restricted k-neighbors regression."""

    def __init__(self, k):
       
        self.bor = None
        self.k = k
        self.model = knn_pipe_var(k)
    "An 'amb_data' dataset with a 'borough' column and a 'rating' column must be used"
    def fit(self, data, bor, feats):
        
        self.bor = bor
        data = data[data.borough == bor]
        
        self.model.fit(data[feats], data.rating)
        
            
    def predict(self, data, bor, feats):
        data = data[data.borough == bor]
        return self.model.predict(data[feats])

# %%
#map each model description to the model
def give_model(list_str):
    mod_descr = list_str[0]
    k_str = list_str[1]
    k = int(float(k_str.replace("k= ", "")))
    knn_pipe = knn_pipe_var(k)
    if mod_descr == 'Best k (geospatial, interact., cuis)':
         return knn_pipe, feats_gic
    if mod_descr == 'Best k (geospatial, bor)':
         return K_Bor(k), feats_g
    if mod_descr == 'Best k (geospatial)':
         return knn_pipe, feats_g
    
models = {key: give_model(value) for key, value in models.items()}

# %% [markdown]
# ### Advanced Clusters

# %%
cluster_df
# Out:
#                           origin  \
# 0         (West Philadelphia, 1)
# 1         (West Philadelphia, 2)
# 2         (West Philadelphia, 0)
# 3    (Northeast Philadelphia, 1)
# 4  (Northeast Philadelphia, 2-3)
# 5    (Northeast Philadelphia, 0)
#
#                                           good_model  \
# 0  (8-neighbors (gen.), [reviews, longitude, lati...
# 1  (17-neighbors (bor.), [reviews, Foreign Born I...
# 2  (Random Forest 5 (bor.), [latitude, longitude,...
# 3  (6-neighbors (gen.), [latitude, longitude, rev...
# 4  (14-neighbors (bor.), [latitude, longitude, re...
# 5  (5-neighbors (bor.), [latitude, longitude, rev...
#
#                                            bad_model  \
# 0  (Linear Regression, [latitude, longitude, revi...
# 1  (Linear Regression, [reviews, latitude, longit...
# 2                                                NaN
# 3  (5-neighbors, [Foreign Born Immigrant %, revie...
# 4                                                NaN
# 5                                                NaN
#
#                                       class_features  \
# 0  [latitude, longitude, photos_count, reviews, M...
# 1  [latitude, longitude, photos_count, reviews, M...
# 2                                                NaN
# 3  [latitude, longitude, reviews, photos_count, M...
# 4                                                NaN
# 5                                                NaN
#
#                                                    0  \
# 0  [[-inf, inf], [-inf, -75.21855545043945], [-in...
# 1  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    1  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, inf], [-inf, -75.25553512573242], [-in...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [238...
# 4                                                NaN
# 5                                                NaN
#
#                                                    2  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, 39.94808769226074], [-75.2555351257324...
# 2                                                NaN
# 3  [[-inf, inf], [-75.03024673461914, inf], [-inf...
# 4                                                NaN
# 5                                                NaN
#
#                                                    3  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[39.94808769226074, inf], [-75.25553512573242...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 4                                                NaN
# 5                                                NaN
#
#                                                    4  \
# 0  [[39.95686149597168, inf], [-75.21855545043945...
# 1                                                NaN
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.06171417236328], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    5
# 0  [[-inf, inf], [-75.19183731079102, inf], [-inf...
# 1                                                NaN
# 2                                                NaN
# 3  [[40.040489196777344, inf], [-inf, inf], [-inf...
# 4                                                NaN
# 5                                                NaN

# %% [markdown]
# We will go one by one through 'cluster_df' when training and predicting these models in the next section. We do however here need to write the methods for producing the clusters within the training and test sets.

# %%
def prod_clusters(data, subsets_rowdf, clus_feats):
    subsets = {i: subsets_rowdf.iloc[i] for i in range(len(subsets_rowdf))}
    bad = def_cluster(data, subsets, clus_feats)
    index_to_remove = set(bad.index.tolist())
    index = set(data.index.tolist())
    index = index.difference(index_to_remove)
    index = [*index]
    good = data.loc[index]
    return good, bad

# %% [markdown]
# ## Full Training and Testing of Models

# %%
models
# Out:
# {'Allegheny West': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Bella Vista': (<__main__.K_Bor at 0x17c8cd9a0>, ['latitude', 'longitude']),
#  'Bensalem': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=4))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Center City': (<__main__.K_Bor at 0x17c8cdb80>, ['latitude', 'longitude']),
#  'Center City East': (<__main__.K_Bor at 0x17c8cdc40>,
#   ['latitude', 'longitude']),
#  'Chestnut Hill': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=2))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'East Germantown': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'East Kensington': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=3))]),
#   ['latitude', 'longitude']),
#  'East Passyunk Crossing': (<__main__.K_Bor at 0x17c8cd010>,
#   ['latitude', 'longitude']),
#  'Elmwood Park': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=2))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Essington': (<__main__.K_Bor at 0x17c8cdee0>, ['latitude', 'longitude']),
#  'Fairhill': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=4))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Fairmount': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Feltonville': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Fishtown': (<__main__.K_Bor at 0x17c8ce330>, ['latitude', 'longitude']),
#  'Fox Chase': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Frankford': (<__main__.K_Bor at 0x17c8ce480>, ['latitude', 'longitude']),
#  'Germantown': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=4))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Harrowgate': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Huntingdon Valley': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=1))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
# ...
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Strawberry Mansion': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=3))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Tacony': (Pipeline(steps=[('scale', StandardScaler()), ('knn', KNeighborsRegressor())]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant']),
#  'Unlabeled': (<__main__.K_Bor at 0x17c8ec590>, ['latitude', 'longitude']),
#  'Whitman': (Pipeline(steps=[('scale', StandardScaler()),
#                   ('knn', KNeighborsRegressor(n_neighbors=4))]),
#   ['latitude',
#    'longitude',
#    'reviews',
#    'photos_count',
#    'Seafood restaurant',
#    'Restaurant',
#    'Portuguese restaurant',
#    'Pizza restaurant',
#    'Chinese restaurant',
#    'American restaurant',
#    'Barbecue restaurant',
#    'Chicken restaurant',
#    'Indian restaurant',
#    'New American restaurant',
#    'French restaurant',
#    'Bar & grill',
#    'Indonesian restaurant',
#    'Kosher restaurant',
#    'Mexican restaurant',
#    'Diner',
#    'Asian restaurant',
#    'Bakery',
#    'Coffee shop',
#    'Chicken wings restaurant',
#    'Entertainment agency',
#    'Jamaican restaurant',
#    'Sandwich shop',
#    'Shabu-shabu restaurant',
#    'Brunch restaurant',
#    'Korean restaurant',
#    'Thai restaurant',
#    'Caribbean restaurant',
#    'Latin American restaurant',
#    'Fast food restaurant',
#    'Italian restaurant',
#    'Breakfast restaurant',
#    'Creperie',
#    'Southern restaurant (US)',
#    'Salvadoran restaurant',
#    'Cafe',
#    'Puerto Rican restaurant',
#    'Vegetarian restaurant',
#    'Japanese restaurant',
#    'Nepalese restaurant',
#    'Cheesesteak restaurant',
#    'Hotel',
#    'Soul food restaurant',
#    'Middle Eastern restaurant',
#    'Vietnamese restaurant',
#    'Mediterranean restaurant',
#    'Vegan restaurant',
#    'Ramen restaurant',
#    'Cooking class',
#    'Irish pub',
#    'Buffet restaurant',
#    'Pizza delivery',
#    'Turkish restaurant',
#    'Brewery',
#    'Honduran restaurant',
#    'Steak house',
#    'Sushi restaurant',
#    'Malaysian restaurant',
#    'Bed & breakfast',
#    'Takeout Restaurant',
#    'Greek restaurant',
#    'Brewpub',
#    'Beer store',
#    'Chinese takeaway',
#    'West African restaurant',
#    'Gastropub',
#    'Tibetan restaurant',
#    'Pizza Takeout',
#    'African restaurant',
#    'Grocery store',
#    'Donut shop',
#    'Bar',
#    'Brazilian restaurant',
#    'Falafel restaurant',
#    'Oyster bar restaurant',
#    'Convenience store',
#    'Tex-Mex restaurant',
#    'Halal restaurant',
#    'Health food restaurant',
#    'Bistro',
#    'Spanish restaurant',
#    'Dominican restaurant',
#    'Pub',
#    'Sports bar',
#    'European restaurant',
#    'Ice cream shop',
#    'Taco restaurant',
#    'Deli',
#    'Organic restaurant',
#    'Russian restaurant',
#    'Beer garden',
#    'Southern Italian restaurant',
#    'Afghan restaurant',
#    'Bagel shop',
#    'Ethiopian restaurant',
#    'Fish & chips restaurant',
#    'Fresh food market',
#    'Pennsylvania Dutch restaurant',
#    'Hamburger restaurant',
#    'Sichuan restaurant',
#    'Lebanese restaurant',
#    'Poke bar',
#    'Uzbeki restaurant',
#    'Cafeteria',
#    'Guatemalan restaurant',
#    'Asian fusion restaurant',
#    'Haitian restaurant',
#    'Catering equipment rental service',
#    'Israeli restaurant',
#    'Eritrean restaurant',
#    'Hot pot restaurant',
#    'Food and drink',
#    'Sicilian restaurant',
#    'Beer hall',
#    'Cambodian restaurant',
#    'Eclectic restaurant',
#    'Irish restaurant',
#    'Crab house',
#    'Salad shop',
#    'Club',
#    'Dim sum restaurant',
#    'Colombian restaurant',
#    'Hoagie restaurant',
#    'Cajun restaurant',
#    'Traditional restaurant',
#    'Liquor store',
#    'Cocktail bar',
#    'Pretzel store',
#    'Gas station',
#    'Winery',
#    'Georgian restaurant',
#    'Korean barbecue restaurant',
#    'Polish restaurant',
#    'Bangladeshi restaurant',
#    'Dessert shop',
#    'Delivery Restaurant',
#    'Açaí shop',
#    'Peruvian restaurant',
#    'Fine dining restaurant',
#    'Pho restaurant',
#    'Pakistani restaurant',
#    'Association / Organization',
#    'Karaoke bar',
#    'Filipino restaurant',
#    'Caterer',
#    'Poultry store',
#    'Hookah bar',
#    'Sushi takeaway',
#    'Gyro restaurant',
#    'Venezuelan restaurant',
#    'Delivery Chinese restaurant',
#    'Modern Indian restaurant',
#    'South Indian restaurant',
#    'Yemeni restaurant',
#    'Tapas restaurant',
#    'Noodle shop',
#    'Market',
#    'Amusement center',
#    'Ecuadorian restaurant',
#    'Traditional American restaurant',
#    'Fried chicken takeaway',
#    'Grill',
#    'Cuban restaurant',
#    'Mobile caterer',
#    'Event venue',
#    'Southeast Asian restaurant',
#    'Bubble tea store',
#    'Moroccan restaurant'])}

# %%
cluster_df
# Out:
#                           origin  \
# 0         (West Philadelphia, 1)
# 1         (West Philadelphia, 2)
# 2         (West Philadelphia, 0)
# 3    (Northeast Philadelphia, 1)
# 4  (Northeast Philadelphia, 2-3)
# 5    (Northeast Philadelphia, 0)
#
#                                           good_model  \
# 0  (8-neighbors (gen.), [reviews, longitude, lati...
# 1  (17-neighbors (bor.), [reviews, Foreign Born I...
# 2  (Random Forest 5 (bor.), [latitude, longitude,...
# 3  (6-neighbors (gen.), [latitude, longitude, rev...
# 4  (14-neighbors (bor.), [latitude, longitude, re...
# 5  (5-neighbors (bor.), [latitude, longitude, rev...
#
#                                            bad_model  \
# 0  (Linear Regression, [latitude, longitude, revi...
# 1  (Linear Regression, [reviews, latitude, longit...
# 2                                                NaN
# 3  (5-neighbors, [Foreign Born Immigrant %, revie...
# 4                                                NaN
# 5                                                NaN
#
#                                       class_features  \
# 0  [latitude, longitude, photos_count, reviews, M...
# 1  [latitude, longitude, photos_count, reviews, M...
# 2                                                NaN
# 3  [latitude, longitude, reviews, photos_count, M...
# 4                                                NaN
# 5                                                NaN
#
#                                                    0  \
# 0  [[-inf, inf], [-inf, -75.21855545043945], [-in...
# 1  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    1  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, inf], [-inf, -75.25553512573242], [-in...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [238...
# 4                                                NaN
# 5                                                NaN
#
#                                                    2  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, 39.94808769226074], [-75.2555351257324...
# 2                                                NaN
# 3  [[-inf, inf], [-75.03024673461914, inf], [-inf...
# 4                                                NaN
# 5                                                NaN
#
#                                                    3  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[39.94808769226074, inf], [-75.25553512573242...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 4                                                NaN
# 5                                                NaN
#
#                                                    4  \
# 0  [[39.95686149597168, inf], [-75.21855545043945...
# 1                                                NaN
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.06171417236328], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    5
# 0  [[-inf, inf], [-75.19183731079102, inf], [-inf...
# 1                                                NaN
# 2                                                NaN
# 3  [[40.040489196777344, inf], [-inf, inf], [-inf...
# 4                                                NaN
# 5                                                NaN

# %%
#fit models to training set
for bor in models.keys():
    
    model = models[bor][0]
    feats = models[bor][1]
    if isinstance(model, K_Bor):
        model.fit(rd_train, bor, feats)
    else:
        model.fit(rd_train[feats], rd_train.rating)


    #training on west philly
    wp = rd_train[rd_train.borough == 'West Philadelphia']
    subset_row = cluster_df.iloc[0, -6:]
    clust_feats = cluster_df.loc[0, 'class_features']
    good_feats = cluster_df.loc[0, 'good_model'][1]
    bad_feats = cluster_df.loc[0, 'bad_model'][1]
    wp_one_good, wp_one_bad = prod_clusters(wp[wp.range == '1'], subset_row, clust_feats)
    wp_one_good = pd.concat([wp_one_good, wp.loc[wp.range == '3']], axis = 0)
    knn_wp_one = KNeighborsRegressor(8)
    mlr_wp_one = LinearRegression()
    knn_wp_one.fit(rd_train[good_feats], rd_train.rating)
    mlr_wp_one.fit(wp_one_bad[bad_feats], wp_one_bad.rating)

    subset_row = cluster_df.iloc[1, -6:-2]
    clust_feats = cluster_df.loc[1, 'class_features']
    good_feats = cluster_df.loc[1, 'good_model'][1]
    bad_feats = cluster_df.loc[1, 'bad_model'][1]
    wp_two_good, wp_two_bad = prod_clusters(wp[wp.range == '2'], subset_row, clust_feats)
    knn_wp_two = KNeighborsRegressor(17)
    mlr_wp_two = LinearRegression()
    knn_wp_two.fit(wp[wp.range == '2'][good_feats], wp[wp.range == '2'].rating)
    mlr_wp_two.fit(wp_two_bad[bad_feats], wp_two_bad.rating)

    wp_zer = wp[wp.range == '0']
    feats = cluster_df.loc[2, 'good_model'][1]
    rf = rf_var(feats)
    rf.fit(wp_zer[feats], wp_zer.rating)

    #training on northeast philly
    ne = rd_train[rd_train.borough == 'Northeast Philadelphia']
    subset_row = cluster_df.iloc[3, -6:]
    clust_feats = cluster_df.loc[3, 'class_features']
    good_feats = cluster_df.loc[3, 'good_model'][1]
    bad_feats = cluster_df.loc[3, 'bad_model'][1]
    ne_one_good, ne_one_bad = prod_clusters(ne[ne.range == '1'], subset_row, clust_feats)
    knn_ne_one_g = KNeighborsRegressor(6)
    knn_ne_one_b = KNeighborsRegressor(5)
    knn_ne_one_g.fit(rd_train[good_feats], rd_train.rating)
    knn_ne_one_b.fit(ne_one_bad[bad_feats], ne_one_bad.rating)

    ne_two = rd_train[(rd_train.borough == 'Northeast Philadelphia') & ((rd_train.range == '2') | (rd_train.range == "3"))]
    ne_zer = rd_train[(rd_train.borough == 'Northeast Philadelphia') & (rd_train.range == '0')]
    knn_ne_two = KNeighborsRegressor(14)
    knn_ne_zer = KNeighborsRegressor(5)
    two_feats = cluster_df.loc[4, 'good_model'][1]
    zer_feats = cluster_df.loc[5, 'good_model'][1]
    knn_ne_two.fit(ne_two[two_feats], ne_two.rating)
    knn_ne_zer.fit(ne_zer[zer_feats], ne_zer.rating)

# %%
#test whether rd_test contains any price levels outside of what's considered for NE and W Philly
spec_bors = rd_test[(rd_test.borough == 'Northeast Philadelphia') | (rd_test.borough == 'West Philadelphia')]

spec_bors.range.unique()
# Out:
# array(['1', '2', '0', '3'], dtype=object)

# %%
#obtain the predictions on the test set
preds = np.array([])
ratings = np.array([])
bor_rmses = {}
boroughs = rd_test.borough.unique()
for bor in boroughs:
    if bor not in ['Northeast Philadelphia', 'West Philadelphia']: 
        model = models[bor][0]
        feats = models[bor][1]
        bor_df = rd_test[rd_test.borough == bor]
        ratings = np.concatenate((ratings, bor_df.rating))
        if isinstance(model, K_Bor):
            bor_preds = model.predict(rd_test, bor, feats)
            preds = np.concatenate((preds, bor_preds))
            bor_rmses[bor] = root_mean_squared_error(bor_preds, bor_df.rating)
        else:
            bor_preds= model.predict(bor_df[feats])
            preds = np.concatenate((preds, bor_preds))
            bor_rmses[bor] = root_mean_squared_error(bor_preds, bor_df.rating)
    
    #prediction on west philly
    wp = rd_test[rd_test.borough == 'West Philadelphia']
    subset_row = cluster_df.iloc[0, -6:]
    clust_feats = cluster_df.loc[0, 'class_features']
    good_feats = cluster_df.loc[0, 'good_model'][1]
    bad_feats = cluster_df.loc[0, 'bad_model'][1]
    wp_one_good, wp_one_bad = prod_clusters(wp[wp.range == '1'], subset_row, clust_feats)
    wp_one_good = pd.concat([wp_one_good, wp.loc[wp.range == '3']], axis = 0)
   
    wp_preds = knn_wp_one.predict(wp_one_good[good_feats])
    lin_preds = mlr_wp_one.predict(wp_one_bad[bad_feats])
    for j in range(len(lin_preds)):
        if lin_preds[j] > 5.0:
            lin_preds[j] = 5.0
    wp_preds = np.concatenate((wp_preds, lin_preds))
    
    subset_row = cluster_df.iloc[1, -6:-2]
    clust_feats = cluster_df.loc[1, 'class_features']
    good_feats = cluster_df.loc[1, 'good_model'][1]
    bad_feats = cluster_df.loc[1, 'bad_model'][1]
    wp_two_good, wp_two_bad = prod_clusters(wp[wp.range == '2'], subset_row, clust_feats)

    wp_preds = np.concatenate((wp_preds, knn_wp_two.predict(wp_two_good[good_feats])))
    lin_preds = mlr_wp_two.predict(wp_two_bad[bad_feats])
    for j in range(len(lin_preds)): #we ensure that the linear model only returns outputs within the allowed range
        if lin_preds[j] > 5.0:
            lin_preds[j] = 5.0
    wp_preds = np.concatenate((wp_preds, lin_preds))

    wp_zer = wp[wp.range == '0']
    feats = cluster_df.loc[2, 'good_model'][1]
    wp_preds = np.concatenate((wp_preds, rf.predict(wp_zer[feats])))
    preds = np.concatenate((preds, wp_preds))
    wp_ratings_arr = np.concatenate((wp_one_good.rating, wp_one_bad.rating, wp_two_good.rating, wp_two_bad.rating,
                                wp_zer.rating))
    ratings = np.concatenate((ratings, wp_ratings_arr))
    bor_rmses['West Philadelphia'] = root_mean_squared_error(wp_preds, wp_ratings_arr)

    #prediction on ne philly
    ne = rd_test[rd_test.borough == 'Northeast Philadelphia']
    subset_row = cluster_df.iloc[3, -6:]
    clust_feats = cluster_df.loc[3, 'class_features']
    good_feats = cluster_df.loc[3, 'good_model'][1]
    bad_feats = cluster_df.loc[3, 'bad_model'][1]
    ne_one_good, ne_one_bad = prod_clusters(ne[ne.range == '1'], subset_row, clust_feats)
  
    ne_preds = knn_ne_one_g.predict(ne_one_good[good_feats])
    ne_preds = np.concatenate((ne_preds, knn_ne_one_b.predict(ne_one_bad[bad_feats])))

    ne_two = rd_test[(rd_test.borough == 'Northeast Philadelphia') & ((rd_test.range == '2') | (rd_test.range == "3"))]
    ne_zer = rd_test[(rd_test.borough == 'Northeast Philadelphia') & (rd_test.range == '0')]
    two_feats = cluster_df.loc[4, 'good_model'][1]
    zer_feats = cluster_df.loc[5, 'good_model'][1]

    ne_preds = np.concatenate((ne_preds, knn_ne_two.predict(ne_two[two_feats])))
    ne_preds = np.concatenate((ne_preds, knn_ne_zer.predict(ne_zer[zer_feats])))
    preds = np.concatenate((preds, ne_preds))
    ne_ratings_arr = np.concatenate((ne_one_good.rating, ne_one_bad.rating, ne_two.rating, ne_zer.rating))
    ratings = np.concatenate((ratings, ne_ratings_arr))
    bor_rmses['Northeast Philadelphia'] = root_mean_squared_error(ne_preds, ne_ratings_arr)

rmse = root_mean_squared_error(ratings, preds)
print(f"The RMSE for our models' predictions on the test set is {rmse: .3f}.")
# Out:
# The RMSE for our models' predictions on the test set is  0.731.

# %%
dict(sorted(bor_rmses.items()))
# Out:
# {'Allegheny West': 0.6331403214664716,
#  'Bella Vista': 0.3754626775356267,
#  'Bensalem': 0.251246890528022,
#  'Center City': 0.34715490623872775,
#  'Center City East': 0.3347006547676399,
#  'Chestnut Hill': 0.33837848631377254,
#  'East Germantown': 0.7465029582437479,
#  'East Kensington': 0.7039570693980957,
#  'East Passyunk Crossing': 0.18850918886280893,
#  'Elmwood Park': 0.23213980461973538,
#  'Essington': 0.19002923751652234,
#  'Fairhill': 0.20891585227869464,
#  'Fairmount': 0.42308391602612366,
#  'Feltonville': 0.39070449191172596,
#  'Fishtown': 0.3901676168402104,
#  'Fox Chase': 0.23966643486312403,
#  'Frankford': 0.5395235993779273,
#  'Germantown': 0.22684429314693677,
#  'Harrowgate': 0.26419689627245846,
#  'Kingsessing': 0.4496912521077347,
#  'Lester': 0.10000000000000053,
#  'Lower Moyamensing': 0.22079402165819573,
#  'Mount Airy': 0.3320240955111541,
#  'Newbold': 0.3560196623783581,
#  'Nicetown–Tioga': 0.3577708763999663,
#  'North Philadelphia': 0.7022696125389822,
#  'North Philadelphia East': 0.43949732051156143,
#  'Northeast Philadelphia': 0.49512029531005536,
#  'Northern Liberties': 0.20412414523193154,
#  'Ogontz': 0.7036511919978534,
#  'Old City': 0.09999999999999964,
#  'Olde Kensington': 0.08539125638299648,
#  'Olde Richmond': 0.6198117993929019,
#  'Olney-Oak Lane': 0.4018894767409959,
#  'Pennsport': 0.10000000000000053,
#  'Port Richmond': 0.2950706130177427,
#  'Rittenhouse Square': 0.3015375163016601,
#  'Roxborough-Manayunk': 0.4415183592314839,
#  'Sharswood': 0.3857142857142857,
#  'South Philadelphia': 0.363726235228569,
#  'South Philadelphia East': 0.25331140255951123,
#  'Southwark': 0.3295017884191658,
#  'Southwest Center City': 0.3811402066731575,
#  'Southwest Philadelphia': 0.6050895250566924,
#  'Stanton': 0.33541019662496824,
#  'Stenton': 0.3686970300938156,
#  'Strawberry Mansion': 0.26915505650915134,
#  'Tacony': 0.2362202362203541,
#  'Unlabeled': 0.458378785625067,
#  'West Philadelphia': 0.9890649025436586,
#  'Whitman': 0.11180339887498968}

# %% [markdown]
# ## Assessment

# %% [markdown]
# It appears that our deconstruction strategy failed spectacularly, at least for West Philly. We briefly examine whether worse results were also returned by the deconstruction on NE Philly.

# %%
cluster_df
# Out:
#                           origin  \
# 0         (West Philadelphia, 1)
# 1         (West Philadelphia, 2)
# 2         (West Philadelphia, 0)
# 3    (Northeast Philadelphia, 1)
# 4  (Northeast Philadelphia, 2-3)
# 5    (Northeast Philadelphia, 0)
#
#                                           good_model  \
# 0  (8-neighbors (gen.), [reviews, longitude, lati...
# 1  (17-neighbors (bor.), [reviews, Foreign Born I...
# 2  (Random Forest 5 (bor.), [latitude, longitude,...
# 3  (6-neighbors (gen.), [latitude, longitude, rev...
# 4  (14-neighbors (bor.), [latitude, longitude, re...
# 5  (5-neighbors (bor.), [latitude, longitude, rev...
#
#                                            bad_model  \
# 0  (Linear Regression, [latitude, longitude, revi...
# 1  (Linear Regression, [reviews, latitude, longit...
# 2                                                NaN
# 3  (5-neighbors, [Foreign Born Immigrant %, revie...
# 4                                                NaN
# 5                                                NaN
#
#                                       class_features  \
# 0  [latitude, longitude, photos_count, reviews, M...
# 1  [latitude, longitude, photos_count, reviews, M...
# 2                                                NaN
# 3  [latitude, longitude, reviews, photos_count, M...
# 4                                                NaN
# 5                                                NaN
#
#                                                    0  \
# 0  [[-inf, inf], [-inf, -75.21855545043945], [-in...
# 1  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    1  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, inf], [-inf, -75.25553512573242], [-in...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.03024673461914], [238...
# 4                                                NaN
# 5                                                NaN
#
#                                                    2  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[-inf, 39.94808769226074], [-75.2555351257324...
# 2                                                NaN
# 3  [[-inf, inf], [-75.03024673461914, inf], [-inf...
# 4                                                NaN
# 5                                                NaN
#
#                                                    3  \
# 0  [[-inf, 39.95686149597168], [-75.2185554504394...
# 1  [[39.94808769226074, inf], [-75.25553512573242...
# 2                                                NaN
# 3  [[-inf, inf], [-inf, inf], [-inf, inf], [-inf,...
# 4                                                NaN
# 5                                                NaN
#
#                                                    4  \
# 0  [[39.95686149597168, inf], [-75.21855545043945...
# 1                                                NaN
# 2                                                NaN
# 3  [[-inf, inf], [-inf, -75.06171417236328], [-in...
# 4                                                NaN
# 5                                                NaN
#
#                                                    5
# 0  [[-inf, inf], [-75.19183731079102, inf], [-inf...
# 1                                                NaN
# 2                                                NaN
# 3  [[40.040489196777344, inf], [-inf, inf], [-inf...
# 4                                                NaN
# 5                                                NaN

# %%
knn_rmse = root_mean_squared_error(ne_one_bad.rating, knn_ne_one_g.predict(ne_one_bad[good_feats]))

knn_b_rmse = root_mean_squared_error(ne_one_bad.rating, knn_ne_one_b.predict(ne_one_bad[bad_feats]))


knn_rmse, knn_b_rmse
# Out:
# (0.39680436452199425, 0.5880476171195664)

# %% [markdown]
# Indeed the deconstruction estimate is worse here too. In hindsight, there may be a rationale for why deconstruction performed so badly on the test set, namely the sway of outliers. When determining the 'large error' set, for lack of immediate insight, we compiled from every fold of the associated cross-validation. But this runs counter to the core philosophy of cross-validation. Additionally, the idea underlying deconstruction may not be robust itself as posed. To simply assume that all sizable errors together point to a divergent, objective statistical trend ignores the effect of outliers. In hindsight, it would have been better if we had incorporated bootstrapping when using the model errors to derive a feature-defined cluster.

# %% [markdown]
# For the sake of completeness, we record the test results when deconstruction is not applied.

# %%
#fit models to training set
for bor in models.keys():
    
    model = models[bor][0]
    feats = models[bor][1]
    if isinstance(model, K_Bor):
        model.fit(rd_train, bor, feats)
    else:
        model.fit(rd_train[feats], rd_train.rating)


    #training on west philly
    wp = rd_train[rd_train.borough == 'West Philadelphia']
    
    good_feats = cluster_df.loc[0, 'good_model'][1]
    
    wp_one = wp[(wp.range == '1') | (wp.range == '3')]
    
    knn_wp_one = KNeighborsRegressor(8)
 
    knn_wp_one.fit(rd_train[good_feats], rd_train.rating)
    

    good_feats = cluster_df.loc[1, 'good_model'][1]
    
    wp_two = wp[wp.range == '2']
    knn_wp_two = KNeighborsRegressor(17)
    
    knn_wp_two.fit(wp_two[good_feats], wp_two.rating)
    

    wp_zer = wp[wp.range == '0']
    feats = cluster_df.loc[2, 'good_model'][1]
    rf = rf_var(feats)
    rf.fit(wp_zer[feats], wp_zer.rating)

    #training on northeast philly
    ne = rd_train[rd_train.borough == 'Northeast Philadelphia']
    
    good_feats = cluster_df.loc[3, 'good_model'][1]
    
    ne_one = ne[ne.range == '1']
    knn_ne_one_g = KNeighborsRegressor(6)
    
    knn_ne_one_g.fit(rd_train[good_feats], rd_train.rating)
    

    ne_two = rd_train[(rd_train.borough == 'Northeast Philadelphia') & ((rd_train.range == '2') | (rd_train.range == "3"))]
    ne_zer = rd_train[(rd_train.borough == 'Northeast Philadelphia') & (rd_train.range == '0')]
    knn_ne_two = KNeighborsRegressor(14)
    knn_ne_zer = KNeighborsRegressor(5)
    two_feats = cluster_df.loc[4, 'good_model'][1]
    zer_feats = cluster_df.loc[5, 'good_model'][1]
    knn_ne_two.fit(ne_two[two_feats], ne_two.rating)
    knn_ne_zer.fit(ne_zer[zer_feats], ne_zer.rating)

# %%
#obtain the predictions on the test set
preds = np.array([])
ratings = np.array([])
bor_rmses = {}
boroughs = rd_test.borough.unique()
for bor in boroughs:
    if bor not in ['Northeast Philadelphia', 'West Philadelphia']: 
        model = models[bor][0]
        feats = models[bor][1]
        bor_df = rd_test[rd_test.borough == bor]
        ratings = np.concatenate((ratings, bor_df.rating))
        if isinstance(model, K_Bor):
            bor_preds = model.predict(rd_test, bor, feats)
            preds = np.concatenate((preds, bor_preds))
            bor_rmses[bor] = root_mean_squared_error(bor_preds, bor_df.rating)
        else:
            bor_preds= model.predict(bor_df[feats])
            preds = np.concatenate((preds, bor_preds))
            bor_rmses[bor] = root_mean_squared_error(bor_preds, bor_df.rating)
    
    #prediction on west philly
    wp = rd_test[rd_test.borough == 'West Philadelphia']
    good_feats = cluster_df.loc[0, 'good_model'][1]
    wp_one = wp[(wp.range == '1') | (wp.range == '3')]
    
   
    wp_preds = knn_wp_one.predict(wp_one[good_feats])
    
    good_feats = cluster_df.loc[1, 'good_model'][1]
    wp_two = wp[wp.range == '2']

    wp_preds = np.concatenate((wp_preds, knn_wp_two.predict(wp_two[good_feats])))
    

    wp_zer = wp[wp.range == '0']
    feats = cluster_df.loc[2, 'good_model'][1]
    wp_preds = np.concatenate((wp_preds, rf.predict(wp_zer[feats])))
    preds = np.concatenate((preds, wp_preds))
    wp_ratings_arr = np.concatenate((wp_one.rating, wp_two.rating,
                                wp_zer.rating))
    ratings = np.concatenate((ratings, wp_ratings_arr))
    bor_rmses['West Philadelphia'] = root_mean_squared_error(wp_preds, wp_ratings_arr)

    #prediction on ne philly
    ne = rd_test[rd_test.borough == 'Northeast Philadelphia']
    good_feats = cluster_df.loc[3, 'good_model'][1]
    ne_one = ne[ne.range == '1']
  
    ne_preds = knn_ne_one_g.predict(ne_one[good_feats])

    ne_two = rd_test[(rd_test.borough == 'Northeast Philadelphia') & ((rd_test.range == '2') | (rd_test.range == "3"))]
    ne_zer = rd_test[(rd_test.borough == 'Northeast Philadelphia') & (rd_test.range == '0')]
    two_feats = cluster_df.loc[4, 'good_model'][1]
    zer_feats = cluster_df.loc[5, 'good_model'][1]

    ne_preds = np.concatenate((ne_preds, knn_ne_two.predict(ne_two[two_feats])))
    ne_preds = np.concatenate((ne_preds, knn_ne_zer.predict(ne_zer[zer_feats])))
    preds = np.concatenate((preds, ne_preds))
    ne_ratings_arr = np.concatenate((ne_one.rating, ne_two.rating, ne_zer.rating))
    ratings = np.concatenate((ratings, ne_ratings_arr))
    bor_rmses['Northeast Philadelphia'] = root_mean_squared_error(ne_preds, ne_ratings_arr)

rmse = root_mean_squared_error(ratings, preds)
print(f"The RMSE for our models' predictions (without deconstruction) on the test set is {rmse: .3f}.")
# Out:
# The RMSE for our models' predictions (without deconstruction) on the test set is  0.469.

# %%
dict(sorted(bor_rmses.items()))
# Out:
# {'Allegheny West': 0.6331403214664716,
#  'Bella Vista': 0.3754626775356267,
#  'Bensalem': 0.251246890528022,
#  'Center City': 0.34715490623872775,
#  'Center City East': 0.3347006547676399,
#  'Chestnut Hill': 0.33837848631377254,
#  'East Germantown': 0.7465029582437479,
#  'East Kensington': 0.7039570693980957,
#  'East Passyunk Crossing': 0.18850918886280893,
#  'Elmwood Park': 0.23213980461973538,
#  'Essington': 0.19002923751652234,
#  'Fairhill': 0.20891585227869464,
#  'Fairmount': 0.42308391602612366,
#  'Feltonville': 0.39070449191172596,
#  'Fishtown': 0.3901676168402104,
#  'Fox Chase': 0.23966643486312403,
#  'Frankford': 0.5395235993779273,
#  'Germantown': 0.22684429314693677,
#  'Harrowgate': 0.26419689627245846,
#  'Kingsessing': 0.4496912521077347,
#  'Lester': 0.10000000000000053,
#  'Lower Moyamensing': 0.22079402165819573,
#  'Mount Airy': 0.3320240955111541,
#  'Newbold': 0.3560196623783581,
#  'Nicetown–Tioga': 0.3577708763999663,
#  'North Philadelphia': 0.7022696125389822,
#  'North Philadelphia East': 0.43949732051156143,
#  'Northeast Philadelphia': 0.4822734567388402,
#  'Northern Liberties': 0.20412414523193154,
#  'Ogontz': 0.7036511919978534,
#  'Old City': 0.09999999999999964,
#  'Olde Kensington': 0.08539125638299648,
#  'Olde Richmond': 0.6198117993929019,
#  'Olney-Oak Lane': 0.4018894767409959,
#  'Pennsport': 0.10000000000000053,
#  'Port Richmond': 0.2950706130177427,
#  'Rittenhouse Square': 0.3015375163016601,
#  'Roxborough-Manayunk': 0.4415183592314839,
#  'Sharswood': 0.3857142857142857,
#  'South Philadelphia': 0.363726235228569,
#  'South Philadelphia East': 0.25331140255951123,
#  'Southwark': 0.3295017884191658,
#  'Southwest Center City': 0.3811402066731575,
#  'Southwest Philadelphia': 0.6050895250566924,
#  'Stanton': 0.33541019662496824,
#  'Stenton': 0.3686970300938156,
#  'Strawberry Mansion': 0.26915505650915134,
#  'Tacony': 0.2362202362203541,
#  'Unlabeled': 0.458378785625067,
#  'West Philadelphia': 0.4590968060836642,
#  'Whitman': 0.11180339887498968}
