# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %%
rd_train = pd.read_csv("/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/train_data.csv")

# %%
rd_train.head()
# Out:
#                                    name   site  \
# 0  The Legends of Seafood and Soul Food   True
# 1                             Fette Sau   True
# 2                              Cafe Liz  False
# 3                 Plaza Pizza and Grill   True
# 4                      Little Fish BYOB   True
#
#                                             subtypes     category  \
# 0           Seafood restaurant, Soul food restaurant  restaurants
# 1  Restaurant, American restaurant, Barbecue rest...  restaurants
# 2                         Portuguese restaurant, Bar  restaurants
# 3  Pizza restaurant, Breakfast restaurant, Cheese...  restaurants
# 4                                 Seafood restaurant  restaurants
#
#                     type  phone  \
# 0     Seafood restaurant   True
# 1             Restaurant   True
# 2  Portuguese restaurant   True
# 3       Pizza restaurant   True
# 4     Seafood restaurant   True
#
#                                       full_address             borough  \
# ...

# %% [markdown]
# EDA showed that the distribution of ratings for all restaurants is largely mirrored by that of the ratings for "$$", or what we shall call price level 2, restaurants. So, all other restaurants likely may be skewing our previous estimates. Therefore, we analyze the price level 1 restaurants separately first.

# %%
#retain only '$' restaurants

rd_train = rd_train[rd_train.range == '1']

# %%
#we run through the data-modeling1.ipynb notebook using rd_train as just specified
# %run "/Users/dominiquekemp/Documents/GitHub/'Will It Restaurant?'/data-modeling1.ipynb"
# Out:
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# /opt/anaconda3/envs/erdos_spring_2025/lib/python3.12/site-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ...

# %%
#results from all models using price level 1 data
all_models['Number of Restaurants'] = [len(rd_train[rd_train.borough == bor]) for bor in np.sort(rd_train.borough.unique())]
all_models
# Out:
#                          Best k  CV Avg. RMSE  Best k  CV Avg. RMSE  Best k  \
# Borough
# Allegheny West               38      0.269954       5      0.317933       6
# Bella Vista                   1      0.242120       4      0.192432       5
# Bensalem                      2      0.166667      48      0.519444       0
# Center City                  12      0.375324      21      0.457391       5
# Center City East              2      0.414297      50      0.454809      11
# Chestnut Hill                 1      0.369610      38      0.372912       6
# East Germantown              15      0.302769      22      0.420062      10
# East Kensington               2      0.083333      16      0.118750       0
# East Passyunk Crossing        1      0.284721      13      0.351479       4
# Elmwood Park                 10      0.344593       4      0.334522      11
# Essington                    23      0.421739       1      0.325000       0
# ...

# %%
rd_train.to_csv("../'Will It Restaurant?'/level1_data", index = False)

# %%
all_models.to_csv("../'Will It Restaurant?'/level1_modelcomparison.csv", index = False)
